# %%
from PIL import Image
import torch 
import numpy as np
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms, datasets
from torchvision.transforms import ToTensor
import torch.nn.functional as F
import albumentations as A
from albumentations.pytorch import ToTensorV2
import os
from PIL import Image
import torchvision.models as models

import time
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# Set seeds
def set_seeds(seed: int=42):
    """Sets random sets for torch operations.

    Args:
        seed (int, optional): Random seed to set. Defaults to 42.
    """
    # Set the seed for general torch operations
    torch.manual_seed(seed)
    # Set the seed for CUDA torch operations (ones that happen on the GPU)
    torch.cuda.manual_seed(seed)
set_seeds()

# %% [markdown]
# # 1. Prepare Dataset

# %%
class Data_Seg_Class(Dataset):
    def __init__(self, img_class_path, img_seg_path, mask_seg_path, transform=None):
        
        self.classifi_path = img_class_path
        self.img_seg_path = img_seg_path
        self.mask_seg_path = mask_seg_path
        self.transform = transform

        name_labels = ['glioma', 'meningioma', 'no_tumor', 'pituitary']

        # lấy tất các file image trong folder classification
        self.images_filename = []
        for i in name_labels:
            for f in os.listdir(self.classifi_path + f'/{i}') :
                if os.path.isfile(os.path.join(self.classifi_path + f'/{i}', f)):
                    self.images_filename.append(os.path.splitext(f)[0])

        # Load dataset phân loại 1 lần duy nhất
        self.class_dataset = datasets.ImageFolder(self.classifi_path)
        self.label_map = {os.path.splitext(os.path.basename(p))[0]: label for p, label in self.class_dataset.samples}

    def __len__(self):
        return len(self.images_filename)

    def __getitem__(self, idx):
        filename = self.images_filename[idx]

        image_path = os.path.join(self.img_seg_path, filename + '.jpg')
        # kiểm tra file ảnh có trong folder segmentation không
        if os.path.isfile(image_path):
            
            mask_path = os.path.join(self.mask_seg_path, filename + '.png')
            
            # Đọc ảnh và mask
            image = np.array(Image.open(image_path).convert('RGB'))
            mask = np.array(Image.open(mask_path).convert('L'))
            mask = (mask > 127).astype(np.float32)
        else:
            image_path_new = os.path.join(self.classifi_path + '/no_tumor', filename + '.jpg')
            image = image = np.array(Image.open(image_path_new).convert('RGB'))
            mask = np.zeros((512, 512), dtype=np.float32)


        # Augmentation
        if self.transform:
            augmented = self.transform(image=image, mask=mask)
            image = augmented['image']
            mask = augmented['mask']
            mask = torch.unsqueeze(mask, 0)
        # Tìm label tương ứng
        label = self.label_map.get(filename, -1)  # nếu không tìm thấy thì = -1

        return image, mask, label

transform = A.Compose([
        A.Resize(256, 256),
        # A.HorizontalFlip(p=0.5),
        # A.VerticalFlip(p=0.1),
        # A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.2, rotate_limit=30, p=0.5),
        # A.RandomBrightnessContrast(brightness_limit=0.3, contrast_limit=0.3, p=0.5),
        # A.GaussNoise(var_limit=(0.01, 0.05), p=0.3),
        A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
        ToTensorV2()
    ], 
    is_check_shapes=False )

# %%
img_class_path_train = '/kaggle/input/dataset-brain/data/classification_task/train'
img_seg_path_train = '/kaggle/input/dataset-brain/data/segmentation_task/train/images'
mask_seg_path_train = '/kaggle/input/dataset-brain/data/segmentation_task/train/masks'

img_class_path_test = '/kaggle/input/dataset-brain/data/classification_task/test'
img_seg_path_test = '/kaggle/input/dataset-brain/data/segmentation_task/test/images'
mask_seg_path_test = '/kaggle/input/dataset-brain/data/segmentation_task/test/masks'

# %%
train_data = Data_Seg_Class(img_class_path_train, img_seg_path_train, mask_seg_path_train, transform)

# %%
# 1. Tìm kiếm mẫu cho mỗi class
found_samples = {}
num_classes_to_find = 4

# Duyệt qua train_data để nhặt ra mỗi class một ảnh
for i in range(len(train_data)):
    image, mask, label = train_data[i]
    
    # Xử lý nếu label là Tensor
    if isinstance(label, torch.Tensor):
        label = label.item()
    
    # Nếu class này chưa có trong danh sách tìm thấy thì thêm vào
    if label not in found_samples:
        found_samples[label] = (image, mask)
    
    # Nếu đã tìm đủ 4 class thì dừng vòng lặp cho nhanh
    if len(found_samples) == num_classes_to_find:
        break

# Sắp xếp label (0, 1, 2, 3) để hiển thị theo thứ tự
sorted_labels = sorted(found_samples.keys())
num_cols = len(sorted_labels)

# 2. Vẽ hình
if num_cols == 0:
    print("Không tìm thấy dữ liệu nào!")
else:
    # Tạo lưới plot: 2 hàng, số cột = số class tìm được
    fig, ax = plt.subplots(2, num_cols, figsize=(4 * num_cols, 6))

    for i, label in enumerate(sorted_labels):
        image, mask = found_samples[label]

        # --- Hàng 1: Ảnh gốc ---
        # Xử lý để hiển thị đúng định dạng (H, W, C)
        if isinstance(image, torch.Tensor):
            img_show = image.permute(1, 2, 0).cpu().numpy()
            
            # (Tuỳ chọn) Nếu bạn đã Normalize ảnh (trừ mean, chia std), 
            # ảnh hiển thị có thể bị tối hoặc màu lạ. 
            # Dòng dưới đây giúp đưa giá trị về khoảng [0, 1] để dễ nhìn hơn:
            img_show = (img_show - img_show.min()) / (img_show.max() - img_show.min())
        else:
            img_show = image

        # Nếu chỉ có 1 cột (1 class), ax là mảng 1 chiều, nếu nhiều cột là 2 chiều
        if num_cols > 1:
            ax_img = ax[0, i]
            ax_mask = ax[1, i]
        else:
            ax_img = ax[0]
            ax_mask = ax[1]

        ax_img.imshow(img_show)
        ax_img.set_title(f"Class: {label}")
        ax_img.axis('off')

        # --- Hàng 2: Mask ---
        if isinstance(mask, torch.Tensor):
            mask_show = mask.squeeze(0).cpu().numpy()
        else:
            mask_show = mask

        ax_mask.imshow(mask_show, cmap='gray')
        ax_mask.set_title(f"Mask - Class {label}")
        ax_mask.axis('off')

    plt.tight_layout()
    plt.show()

# %%
train_size = int(0.8 * len(train_data))
valid_test_size = len(train_data) - train_size

# Chia dữ liệu thành train (80%) và tạm thời là validation/test (20%)
train_dataset, valid_test_dataset = random_split(train_data, [train_size, valid_test_size])

# Tiếp tục chia valid_test_dataset thành validation (10%) và test (10%)
valid_size = int(0.5 * valid_test_size)
test_size = valid_test_size - valid_size
valid_dataset, test_dataset = random_split(valid_test_dataset, [valid_size, test_size])

# You can check the sizes to verify
print(f"Training set: {len(train_dataset)} samples")
print(f"Validation set: {len(valid_dataset)} samples")
print(f"Test set: {len(test_dataset)} samples")
# Out:
# Training set: 4000 samples
# Validation set: 500 samples
# Test set: 500 samples

# %%
train_loader = DataLoader(train_dataset, shuffle=True, batch_size=32)
valid_loader = DataLoader(valid_dataset, shuffle=False, batch_size=32)
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=32)

# %% [markdown]
# # 3. Load model

# %% [markdown]
# ![image.png](attachment:89883fda-0dcd-4608-8049-de56beee8da6.png)

# %%
class decode(torch.nn.Module):
    def __init__(self, in_channel, middle_channel, out_channel):
        super(decode, self).__init__()
        self.transpose = torch.nn.ConvTranspose2d(in_channel, in_channel, kernel_size=2, stride=2)
        self.conv1 = torch.nn.Conv2d(in_channel + middle_channel, out_channel,  kernel_size=3, stride=1, padding=1)
        self.bn1 = torch.nn.BatchNorm2d(out_channel)
        self.relu1 = torch.nn.ReLU()
        self.indenti1 = torch.nn.Identity()

        self.conv2 = torch.nn.Conv2d(out_channel, out_channel,  kernel_size=3, stride=1, padding=1)
        self.bn2 = torch.nn.BatchNorm2d(out_channel)
        self.relu2 = torch.nn.ReLU()
        self.indenti2 = torch.nn.Identity()


    def forward(self, x1, x2):
        x1 = self.transpose(x1)
        if x1.size() != x2.size():
            x1 = nn.functional.interpolate(x1, size=x2.shape[2:], 
                                            mode='bilinear', align_corners=False)
            
        x = torch.cat([x1, x2], dim=1)
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu1(x)
        x = self.indenti1(x)
        
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu2(x)
        x = self.indenti2(x)
      
        return x

# %%
class MultiTaskModel(nn.Module):
    def __init__(self, n_classes, n_segment, in_channels, input_size=(256,256)):
        super(MultiTaskModel, self).__init__()

        # load pretrained resnet50
        resnet = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V1)

        # encoder
        self.block_input = nn.Sequential(
            resnet.conv1,
            resnet.bn1,
            resnet.relu,
        )
        self.maxpool = resnet.maxpool

        self.encode1 = resnet.layer1
        self.encode2 = resnet.layer2
        self.encode3 = resnet.layer3
        self.encode4 = resnet.layer4

        # decoder

        self.decode1 = decode(2048, 1024, 512)
        self.decode2 = decode(512, 512, 256)
        self.decode3 = decode(256, 256, 128)
        self.decode4 = decode(128, 64, 64)       

        # output segment
        self.segmentation_head = nn.Sequential(
            nn.ConvTranspose2d(64, 32, kernel_size=2, stride=2),
            nn.ReLU(inplace=True),
            nn.Conv2d(32, n_segment, kernel_size=1)  # Output layer
        )
              # output classify
        self.classify = nn.Sequential(
            resnet.avgpool,
            nn.Flatten(),
            nn.Dropout(p=0.5),
            nn.Linear(in_features=2048,
                      out_features=n_classes,
                      bias=True)
        )

    def forward(self, inputs):
        x1 = self.block_input(inputs)
        x1_maxpool = self.maxpool(x1)
        x2 = self.encode1(x1_maxpool)
        x3 = self.encode2(x2)
        x4 = self.encode3(x3)
        x5 = self.encode4(x4)

        x6 = self.decode1(x5, x4)
        x7 = self.decode2(x6, x3)
        x8 = self.decode3(x7, x2)
        x9 = self.decode4(x8, x1)

        

        out_classify = self.classify(x5)
                
        out_segment = self.segmentation_head(x9)
        
        return out_classify, out_segment

# %%
model = MultiTaskModel(n_classes= 4, n_segment=1, in_channels=3, input_size=(256, 256))
model = model.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 206MB/s]

# %% [markdown]
# # 4. Code loss

# %%
class DiceLoss(nn.Module):
    def __init__(self, smooth=1e-6):
        super(DiceLoss, self).__init__()
        self.smooth = smooth

    def forward(self, predictions, targets):
        # 1. Chuyển logits thành xác suất
        predictions = torch.sigmoid(predictions)

        # 2. Flatten: (Batch_Size, Channel, H, W) -> (Batch_Size, -1)
        # Giữ lại chiều Batch_Size để tính riêng từng ảnh
        predictions = predictions.view(predictions.size(0), -1)
        targets = targets.view(targets.size(0), -1)

        # 3. Tính Intersection và Union cho TỪNG ảnh (dim=1)
        intersection = (predictions * targets).sum(dim=1)
        union = predictions.sum(dim=1) + targets.sum(dim=1)

        # 4. Tính Dice cho từng ảnh
        dice = (2. * intersection + self.smooth) / (union + self.smooth)

        # 5. Trả về 1 - dice trung bình của cả batch
        return 1 - dice.mean()

class CombinedLoss(nn.Module):
    def __init__(self, weight_dice=0.5, weight_bce=0.5):
        super(CombinedLoss, self).__init__()
        self.dice = DiceLoss()
        # BCEWithLogitsLoss đã tích hợp Sigmoid bên trong, rất ổn định
        self.bce = nn.BCEWithLogitsLoss() 
        self.weight_dice = weight_dice
        self.weight_bce = weight_bce

    def forward(self, predictions, targets):
        # predictions: Logits (chưa qua sigmoid)
        # targets: Binary mask (0 hoặc 1)
        
        dice_loss = self.dice(predictions, targets)
        bce_loss = self.bce(predictions, targets)
        
        return self.weight_dice * dice_loss + self.weight_bce * bce_loss

# Metrics
def calculate_iou(predictions, targets, threshold=0.5):
    predictions = torch.sigmoid(predictions)
    predictions = (predictions > threshold).float()
    
    intersection = (predictions * targets).sum(dim=(1, 2, 3))
    union = predictions.sum(dim=(1, 2, 3)) + targets.sum(dim=(1, 2, 3)) - intersection
    
    iou = (intersection + 1e-6) / (union + 1e-6)
    return iou.mean()

def calculate_dice(predictions, targets, threshold=0.5):
    predictions = torch.sigmoid(predictions)
    predictions = (predictions > threshold).float()
    
    intersection = (predictions * targets).sum(dim=(1, 2, 3))
    dice = (2. * intersection + 1e-6) / (predictions.sum(dim=(1, 2, 3)) + targets.sum(dim=(1, 2, 3)) + 1e-6)
    return dice.mean()

# %%
class MultiTaskLoss(nn.Module):
  def __init__(self, task_num):
    super(MultiTaskLoss, self).__init__()
    self.task_num = task_num
    # khởi tạo log(sigma^2) = 0
    self.log_vars = nn.Parameter(torch.zeros((task_num)))
    self.loss_sent = CombinedLoss()
    self.loss_classify = nn.CrossEntropyLoss()

  def forward(self, sent_logits, sent_labels, classify_logits, classify_labels):
    loss_sent = self.loss_sent(sent_logits, sent_labels)
    loss_domain = self.loss_classify(classify_logits, classify_labels)

    # log(sigma^2) -> sigma^2
    precision_sent = torch.exp(self.log_vars[0])
    precision_domain = torch.exp(self.log_vars[1])

    loss = torch.log(precision_sent**0.5) + torch.log(precision_domain**0.5) + loss_sent * (1 / (precision_sent*2)) + loss_domain * (1 / (precision_domain*2))

    return loss

# %% [markdown]
# # 5. Train model

# %%
def train(model, criterion, optimizer, train_loader, device):
    model.train()
    total_loss = 0
    corrects = 0
    total_iou = 0
    total_dice = 0
    for i, (images, masks, targets) in enumerate(train_loader):
        optimizer.zero_grad()

        images = images.to(device)
        masks = masks.to(device)
        targets = targets.to(device)
        
        output_class, output_seg = model(images)
        
        loss = criterion(output_seg, masks, output_class, targets)

        _, pred = torch.max(output_class, 1)
        corrects += torch.sum(targets == pred).item()

        loss.backward()
        optimizer.step()

        with torch.no_grad():
            iou = calculate_iou(output_seg, masks)
            dice = calculate_dice(output_seg, masks)
        
        total_loss += loss.item()
        total_iou += iou.item()
        total_dice += dice.item()
    return total_loss / len(train_loader), total_iou/len(train_loader), total_dice/len(train_loader), corrects/len(train_loader.dataset)
def valid(model, criterion, valid_loader, device):
    model.eval()
    with torch.no_grad():
        total_loss = 0
        corrects = 0
        total_iou = 0
        total_dice = 0
        for i, (images, masks, targets) in enumerate(valid_loader):
            images = images.to(device)
            masks = masks.to(device)
            targets = targets.to(device)
    
            output_class, output_seg = model(images)
            loss =criterion(output_seg, masks, output_class, targets)
    
            _, pred = torch.max(output_class, 1)
            corrects += torch.sum(targets == pred).item()
            
            iou = calculate_iou(output_seg, masks)
            dice = calculate_dice(output_seg, masks)
            
            total_loss += loss.item()
            total_iou += iou.item()
            total_dice += dice.item()
    return total_loss / len(valid_loader), total_iou/len(valid_loader), total_dice/len(valid_loader), corrects/len(valid_loader.dataset)

# %%
results = {
    "train_loss" : [],
    "iou_train"  : [],
    "dice_train" : [],
    "acc_train"  : [],
    "valid_loss" : [],
    "iou_valid"  : [],
    "dice_valid" : [],
    "acc_valid"  : []
    }
# configure
criterion = MultiTaskLoss(2)
optimizer = optim.Adam(model.parameters(), lr=0.0001)
epochs = 100
for epoch in range(epochs):
    train_loss, iou_train, dice_train, acc_train = train(model, criterion, optimizer, train_loader, device)
    valid_loss, iou_valid, dice_valid, acc_valid = valid(model, criterion, valid_loader, device)
    
    print(f'Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, IoU Score : {iou_train:.4f}, Dice Score : {dice_train:.4f}, Acc : {acc_train:.4f}')
    print(f'Epoch {epoch+1}/{epochs}, Valid Loss: {valid_loss:.4f}, IoU Score : {iou_valid:.4f}, Dice Score : {dice_valid:.4f}, Acc : {acc_valid:.4f}')
    print('-------------------------------------------------------------------------------------------------------------------------------')

    results["train_loss"].append(train_loss)
    results["iou_train"].append(iou_train)
    results["dice_train"].append(dice_train)
    results["acc_train"].append(acc_train)
    results["valid_loss"].append(valid_loss)
    results["iou_valid"].append(iou_valid)
    results["dice_valid"].append(dice_valid)
    results["acc_valid"].append(acc_valid)
# Out:
# Epoch 1/100, Train Loss: 0.4778, IoU Score : 0.1768, Dice Score : 0.1773, Acc : 0.9117
# Epoch 1/100, Valid Loss: 0.3672, IoU Score : 0.2492, Dice Score : 0.2492, Acc : 0.9660
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 2/100, Train Loss: 0.3166, IoU Score : 0.2070, Dice Score : 0.2070, Acc : 0.9810
# Epoch 2/100, Valid Loss: 0.3018, IoU Score : 0.2492, Dice Score : 0.2492, Acc : 0.9760
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 3/100, Train Loss: 0.2469, IoU Score : 0.2070, Dice Score : 0.2070, Acc : 0.9940
# Epoch 3/100, Valid Loss: 0.2555, IoU Score : 0.2492, Dice Score : 0.2492, Acc : 0.9800
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 4/100, Train Loss: 0.2049, IoU Score : 0.2070, Dice Score : 0.2070, Acc : 0.9935
# Epoch 4/100, Valid Loss: 0.2318, IoU Score : 0.2492, Dice Score : 0.2492, Acc : 0.9700
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 5/100, Train Loss: 0.1742, IoU Score : 0.2070, Dice Score : 0.2070, Acc : 0.9955
# Epoch 5/100, Valid Loss: 0.1909, IoU Score : 0.2492, Dice Score : 0.2492, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 6/100, Train Loss: 0.1665, IoU Score : 0.2070, Dice Score : 0.2070, Acc : 0.9928
# Epoch 6/100, Valid Loss: 0.2015, IoU Score : 0.2492, Dice Score : 0.2492, Acc : 0.9800
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 7/100, Train Loss: 0.1632, IoU Score : 0.2070, Dice Score : 0.2070, Acc : 0.9912
# Epoch 7/100, Valid Loss: 0.1895, IoU Score : 0.2492, Dice Score : 0.2492, Acc : 0.9780
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 8/100, Train Loss: 0.1551, IoU Score : 0.3671, Dice Score : 0.3858, Acc : 0.9932
# Epoch 8/100, Valid Loss: 0.1684, IoU Score : 0.7772, Dice Score : 0.8419, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 9/100, Train Loss: 0.1406, IoU Score : 0.8143, Dice Score : 0.8793, Acc : 0.9985
# Epoch 9/100, Valid Loss: 0.1716, IoU Score : 0.7874, Dice Score : 0.8512, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 10/100, Train Loss: 0.1353, IoU Score : 0.8356, Dice Score : 0.8974, Acc : 0.9998
# Epoch 10/100, Valid Loss: 0.1739, IoU Score : 0.8055, Dice Score : 0.8680, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 11/100, Train Loss: 0.1306, IoU Score : 0.8471, Dice Score : 0.9063, Acc : 1.0000
# Epoch 11/100, Valid Loss: 0.1675, IoU Score : 0.8055, Dice Score : 0.8662, Acc : 0.9920
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 12/100, Train Loss: 0.1277, IoU Score : 0.8499, Dice Score : 0.9072, Acc : 0.9995
# Epoch 12/100, Valid Loss: 0.1680, IoU Score : 0.8014, Dice Score : 0.8626, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 13/100, Train Loss: 0.1271, IoU Score : 0.8505, Dice Score : 0.9067, Acc : 0.9980
# Epoch 13/100, Valid Loss: 0.1847, IoU Score : 0.7946, Dice Score : 0.8568, Acc : 0.9740
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 14/100, Train Loss: 0.1269, IoU Score : 0.8342, Dice Score : 0.8915, Acc : 0.9978
# Epoch 14/100, Valid Loss: 0.1701, IoU Score : 0.7854, Dice Score : 0.8459, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 15/100, Train Loss: 0.1211, IoU Score : 0.8520, Dice Score : 0.9080, Acc : 0.9998
# Epoch 15/100, Valid Loss: 0.1622, IoU Score : 0.7992, Dice Score : 0.8599, Acc : 0.9920
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 16/100, Train Loss: 0.1187, IoU Score : 0.8616, Dice Score : 0.9154, Acc : 0.9995
# Epoch 16/100, Valid Loss: 0.1706, IoU Score : 0.7995, Dice Score : 0.8602, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 17/100, Train Loss: 0.1285, IoU Score : 0.8503, Dice Score : 0.9042, Acc : 0.9912
# Epoch 17/100, Valid Loss: 0.2210, IoU Score : 0.7392, Dice Score : 0.8025, Acc : 0.9560
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 18/100, Train Loss: 0.1392, IoU Score : 0.7908, Dice Score : 0.8484, Acc : 0.9848
# Epoch 18/100, Valid Loss: 0.1792, IoU Score : 0.7619, Dice Score : 0.8232, Acc : 0.9700
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 19/100, Train Loss: 0.1257, IoU Score : 0.8265, Dice Score : 0.8821, Acc : 0.9940
# Epoch 19/100, Valid Loss: 0.1616, IoU Score : 0.7874, Dice Score : 0.8459, Acc : 0.9740
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 20/100, Train Loss: 0.1111, IoU Score : 0.8661, Dice Score : 0.9161, Acc : 0.9982
# Epoch 20/100, Valid Loss: 0.1654, IoU Score : 0.8004, Dice Score : 0.8598, Acc : 0.9780
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 21/100, Train Loss: 0.1082, IoU Score : 0.8789, Dice Score : 0.9260, Acc : 0.9982
# Epoch 21/100, Valid Loss: 0.1441, IoU Score : 0.7982, Dice Score : 0.8533, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 22/100, Train Loss: 0.1049, IoU Score : 0.8518, Dice Score : 0.8971, Acc : 0.9980
# Epoch 22/100, Valid Loss: 0.1497, IoU Score : 0.7965, Dice Score : 0.8522, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 23/100, Train Loss: 0.1021, IoU Score : 0.8631, Dice Score : 0.9063, Acc : 0.9982
# Epoch 23/100, Valid Loss: 0.1491, IoU Score : 0.7959, Dice Score : 0.8514, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 24/100, Train Loss: 0.0975, IoU Score : 0.8905, Dice Score : 0.9315, Acc : 0.9992
# Epoch 24/100, Valid Loss: 0.1669, IoU Score : 0.8052, Dice Score : 0.8615, Acc : 0.9720
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 25/100, Train Loss: 0.0713, IoU Score : 0.9109, Dice Score : 0.9488, Acc : 0.9995
# Epoch 25/100, Valid Loss: 0.1238, IoU Score : 0.8147, Dice Score : 0.8698, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 26/100, Train Loss: 0.0678, IoU Score : 0.8871, Dice Score : 0.9275, Acc : 1.0000
# Epoch 26/100, Valid Loss: 0.1204, IoU Score : 0.7973, Dice Score : 0.8543, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 27/100, Train Loss: 0.0650, IoU Score : 0.9056, Dice Score : 0.9411, Acc : 1.0000
# Epoch 27/100, Valid Loss: 0.1188, IoU Score : 0.7966, Dice Score : 0.8523, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 28/100, Train Loss: 0.0639, IoU Score : 0.9214, Dice Score : 0.9543, Acc : 1.0000
# Epoch 28/100, Valid Loss: 0.1264, IoU Score : 0.8228, Dice Score : 0.8779, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 29/100, Train Loss: 0.0628, IoU Score : 0.9272, Dice Score : 0.9579, Acc : 1.0000
# Epoch 29/100, Valid Loss: 0.1232, IoU Score : 0.8261, Dice Score : 0.8801, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 30/100, Train Loss: 0.0621, IoU Score : 0.9268, Dice Score : 0.9559, Acc : 1.0000
# Epoch 30/100, Valid Loss: 0.1232, IoU Score : 0.8219, Dice Score : 0.8761, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 31/100, Train Loss: 0.0615, IoU Score : 0.9330, Dice Score : 0.9607, Acc : 1.0000
# Epoch 31/100, Valid Loss: 0.1234, IoU Score : 0.8189, Dice Score : 0.8734, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 32/100, Train Loss: 0.0610, IoU Score : 0.9346, Dice Score : 0.9610, Acc : 1.0000
# Epoch 32/100, Valid Loss: 0.1225, IoU Score : 0.8220, Dice Score : 0.8769, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 33/100, Train Loss: 0.0607, IoU Score : 0.9356, Dice Score : 0.9611, Acc : 1.0000
# Epoch 33/100, Valid Loss: 0.1217, IoU Score : 0.8236, Dice Score : 0.8780, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 34/100, Train Loss: 0.0604, IoU Score : 0.9378, Dice Score : 0.9624, Acc : 1.0000
# Epoch 34/100, Valid Loss: 0.1240, IoU Score : 0.8130, Dice Score : 0.8676, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 35/100, Train Loss: 0.0601, IoU Score : 0.9364, Dice Score : 0.9602, Acc : 1.0000
# Epoch 35/100, Valid Loss: 0.1133, IoU Score : 0.8043, Dice Score : 0.8590, Acc : 0.9920
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 36/100, Train Loss: 0.0605, IoU Score : 0.9371, Dice Score : 0.9609, Acc : 0.9998
# Epoch 36/100, Valid Loss: 0.1135, IoU Score : 0.8205, Dice Score : 0.8751, Acc : 0.9920
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 37/100, Train Loss: 0.0596, IoU Score : 0.9429, Dice Score : 0.9657, Acc : 1.0000
# Epoch 37/100, Valid Loss: 0.1126, IoU Score : 0.8001, Dice Score : 0.8551, Acc : 0.9920
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 38/100, Train Loss: 0.0594, IoU Score : 0.9430, Dice Score : 0.9652, Acc : 1.0000
# Epoch 38/100, Valid Loss: 0.1134, IoU Score : 0.8015, Dice Score : 0.8556, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 39/100, Train Loss: 0.0593, IoU Score : 0.9350, Dice Score : 0.9570, Acc : 1.0000
# Epoch 39/100, Valid Loss: 0.1141, IoU Score : 0.7854, Dice Score : 0.8400, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 40/100, Train Loss: 0.0598, IoU Score : 0.9185, Dice Score : 0.9418, Acc : 1.0000
# Epoch 40/100, Valid Loss: 0.1163, IoU Score : 0.7890, Dice Score : 0.8436, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 41/100, Train Loss: 0.0593, IoU Score : 0.9346, Dice Score : 0.9567, Acc : 1.0000
# Epoch 41/100, Valid Loss: 0.1187, IoU Score : 0.8187, Dice Score : 0.8730, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 42/100, Train Loss: 0.0587, IoU Score : 0.9490, Dice Score : 0.9693, Acc : 1.0000
# Epoch 42/100, Valid Loss: 0.1171, IoU Score : 0.7871, Dice Score : 0.8419, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 43/100, Train Loss: 0.0584, IoU Score : 0.9448, Dice Score : 0.9640, Acc : 1.0000
# Epoch 43/100, Valid Loss: 0.1224, IoU Score : 0.8189, Dice Score : 0.8726, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 44/100, Train Loss: 0.0582, IoU Score : 0.9428, Dice Score : 0.9615, Acc : 1.0000
# Epoch 44/100, Valid Loss: 0.1177, IoU Score : 0.8255, Dice Score : 0.8794, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 45/100, Train Loss: 0.0582, IoU Score : 0.9499, Dice Score : 0.9688, Acc : 1.0000
# Epoch 45/100, Valid Loss: 0.1173, IoU Score : 0.7866, Dice Score : 0.8410, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 46/100, Train Loss: 0.0580, IoU Score : 0.9446, Dice Score : 0.9630, Acc : 1.0000
# Epoch 46/100, Valid Loss: 0.1205, IoU Score : 0.7896, Dice Score : 0.8451, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 47/100, Train Loss: 0.0585, IoU Score : 0.9350, Dice Score : 0.9547, Acc : 1.0000
# Epoch 47/100, Valid Loss: 0.1185, IoU Score : 0.7993, Dice Score : 0.8551, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 48/100, Train Loss: 0.0578, IoU Score : 0.9425, Dice Score : 0.9604, Acc : 1.0000
# Epoch 48/100, Valid Loss: 0.1225, IoU Score : 0.7701, Dice Score : 0.8245, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 49/100, Train Loss: 0.0575, IoU Score : 0.9531, Dice Score : 0.9701, Acc : 1.0000
# Epoch 49/100, Valid Loss: 0.1196, IoU Score : 0.7293, Dice Score : 0.7838, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 50/100, Train Loss: 0.0572, IoU Score : 0.9552, Dice Score : 0.9713, Acc : 1.0000
# Epoch 50/100, Valid Loss: 0.1212, IoU Score : 0.7947, Dice Score : 0.8496, Acc : 0.9920
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 51/100, Train Loss: 0.0569, IoU Score : 0.9600, Dice Score : 0.9753, Acc : 1.0000
# Epoch 51/100, Valid Loss: 0.1226, IoU Score : 0.8098, Dice Score : 0.8656, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 52/100, Train Loss: 0.0576, IoU Score : 0.9456, Dice Score : 0.9617, Acc : 1.0000
# Epoch 52/100, Valid Loss: 0.1713, IoU Score : 0.8073, Dice Score : 0.8632, Acc : 0.9720
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 53/100, Train Loss: 0.1281, IoU Score : 0.7710, Dice Score : 0.8206, Acc : 0.9708
# Epoch 53/100, Valid Loss: 0.1494, IoU Score : 0.7608, Dice Score : 0.8175, Acc : 0.9760
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 54/100, Train Loss: 0.0888, IoU Score : 0.8113, Dice Score : 0.8596, Acc : 0.9925
# Epoch 54/100, Valid Loss: 0.1463, IoU Score : 0.7850, Dice Score : 0.8427, Acc : 0.9740
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 55/100, Train Loss: 0.0689, IoU Score : 0.8827, Dice Score : 0.9180, Acc : 0.9975
# Epoch 55/100, Valid Loss: 0.1482, IoU Score : 0.7830, Dice Score : 0.8379, Acc : 0.9740
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 56/100, Train Loss: 0.0675, IoU Score : 0.9030, Dice Score : 0.9326, Acc : 0.9968
# Epoch 56/100, Valid Loss: 0.1250, IoU Score : 0.7681, Dice Score : 0.8250, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 57/100, Train Loss: 0.0608, IoU Score : 0.9311, Dice Score : 0.9545, Acc : 0.9998
# Epoch 57/100, Valid Loss: 0.1233, IoU Score : 0.7842, Dice Score : 0.8397, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 58/100, Train Loss: 0.0592, IoU Score : 0.9369, Dice Score : 0.9569, Acc : 1.0000
# Epoch 58/100, Valid Loss: 0.1233, IoU Score : 0.7756, Dice Score : 0.8312, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 59/100, Train Loss: 0.0581, IoU Score : 0.9444, Dice Score : 0.9624, Acc : 1.0000
# Epoch 59/100, Valid Loss: 0.1273, IoU Score : 0.7886, Dice Score : 0.8442, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 60/100, Train Loss: 0.0573, IoU Score : 0.9474, Dice Score : 0.9637, Acc : 1.0000
# Epoch 60/100, Valid Loss: 0.1272, IoU Score : 0.7992, Dice Score : 0.8555, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 61/100, Train Loss: 0.0572, IoU Score : 0.9499, Dice Score : 0.9653, Acc : 1.0000
# Epoch 61/100, Valid Loss: 0.1307, IoU Score : 0.8001, Dice Score : 0.8561, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 62/100, Train Loss: 0.0566, IoU Score : 0.9570, Dice Score : 0.9715, Acc : 1.0000
# Epoch 62/100, Valid Loss: 0.1288, IoU Score : 0.8055, Dice Score : 0.8618, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 63/100, Train Loss: 0.0565, IoU Score : 0.9600, Dice Score : 0.9740, Acc : 1.0000
# Epoch 63/100, Valid Loss: 0.1285, IoU Score : 0.7919, Dice Score : 0.8478, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 64/100, Train Loss: 0.0563, IoU Score : 0.9600, Dice Score : 0.9735, Acc : 1.0000
# Epoch 64/100, Valid Loss: 0.1309, IoU Score : 0.7993, Dice Score : 0.8554, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 65/100, Train Loss: 0.0564, IoU Score : 0.9599, Dice Score : 0.9734, Acc : 1.0000
# Epoch 65/100, Valid Loss: 0.1315, IoU Score : 0.7941, Dice Score : 0.8503, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 66/100, Train Loss: 0.0561, IoU Score : 0.9617, Dice Score : 0.9747, Acc : 1.0000
# Epoch 66/100, Valid Loss: 0.1317, IoU Score : 0.8128, Dice Score : 0.8690, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 67/100, Train Loss: 0.0560, IoU Score : 0.9580, Dice Score : 0.9707, Acc : 1.0000
# Epoch 67/100, Valid Loss: 0.1290, IoU Score : 0.8101, Dice Score : 0.8657, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 68/100, Train Loss: 0.0560, IoU Score : 0.9637, Dice Score : 0.9761, Acc : 1.0000
# Epoch 68/100, Valid Loss: 0.1272, IoU Score : 0.8039, Dice Score : 0.8600, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 69/100, Train Loss: 0.0558, IoU Score : 0.9634, Dice Score : 0.9755, Acc : 1.0000
# Epoch 69/100, Valid Loss: 0.1311, IoU Score : 0.7988, Dice Score : 0.8549, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 70/100, Train Loss: 0.0557, IoU Score : 0.9641, Dice Score : 0.9760, Acc : 1.0000
# Epoch 70/100, Valid Loss: 0.1326, IoU Score : 0.8008, Dice Score : 0.8572, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 71/100, Train Loss: 0.0557, IoU Score : 0.9673, Dice Score : 0.9792, Acc : 1.0000
# Epoch 71/100, Valid Loss: 0.1334, IoU Score : 0.7907, Dice Score : 0.8466, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 72/100, Train Loss: 0.0557, IoU Score : 0.9557, Dice Score : 0.9675, Acc : 1.0000
# Epoch 72/100, Valid Loss: 0.1301, IoU Score : 0.8005, Dice Score : 0.8570, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 73/100, Train Loss: 0.0555, IoU Score : 0.9686, Dice Score : 0.9800, Acc : 1.0000
# Epoch 73/100, Valid Loss: 0.1286, IoU Score : 0.7976, Dice Score : 0.8535, Acc : 0.9920
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 74/100, Train Loss: 0.0555, IoU Score : 0.9699, Dice Score : 0.9811, Acc : 1.0000
# Epoch 74/100, Valid Loss: 0.1305, IoU Score : 0.7946, Dice Score : 0.8507, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 75/100, Train Loss: 0.0554, IoU Score : 0.9686, Dice Score : 0.9796, Acc : 1.0000
# Epoch 75/100, Valid Loss: 0.1318, IoU Score : 0.8054, Dice Score : 0.8612, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 76/100, Train Loss: 0.0975, IoU Score : 0.8365, Dice Score : 0.8695, Acc : 0.9825
# Epoch 76/100, Valid Loss: 0.2114, IoU Score : 0.6904, Dice Score : 0.7486, Acc : 0.9380
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 77/100, Train Loss: 0.0914, IoU Score : 0.8296, Dice Score : 0.8736, Acc : 0.9885
# Epoch 77/100, Valid Loss: 0.1582, IoU Score : 0.7751, Dice Score : 0.8321, Acc : 0.9660
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 78/100, Train Loss: 0.0670, IoU Score : 0.9064, Dice Score : 0.9354, Acc : 0.9965
# Epoch 78/100, Valid Loss: 0.1260, IoU Score : 0.7499, Dice Score : 0.8060, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 79/100, Train Loss: 0.0598, IoU Score : 0.9258, Dice Score : 0.9464, Acc : 0.9998
# Epoch 79/100, Valid Loss: 0.1396, IoU Score : 0.7768, Dice Score : 0.8321, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 80/100, Train Loss: 0.0579, IoU Score : 0.9361, Dice Score : 0.9526, Acc : 0.9998
# Epoch 80/100, Valid Loss: 0.1306, IoU Score : 0.7593, Dice Score : 0.8141, Acc : 0.9920
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 81/100, Train Loss: 0.0572, IoU Score : 0.9538, Dice Score : 0.9678, Acc : 0.9992
# Epoch 81/100, Valid Loss: 0.1554, IoU Score : 0.7948, Dice Score : 0.8487, Acc : 0.9800
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 82/100, Train Loss: 0.0572, IoU Score : 0.9591, Dice Score : 0.9719, Acc : 0.9990
# Epoch 82/100, Valid Loss: 0.1426, IoU Score : 0.7894, Dice Score : 0.8441, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 83/100, Train Loss: 0.0571, IoU Score : 0.9606, Dice Score : 0.9733, Acc : 0.9995
# Epoch 83/100, Valid Loss: 0.1433, IoU Score : 0.7811, Dice Score : 0.8361, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 84/100, Train Loss: 0.0570, IoU Score : 0.9577, Dice Score : 0.9706, Acc : 0.9995
# Epoch 84/100, Valid Loss: 0.1299, IoU Score : 0.7854, Dice Score : 0.8412, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 85/100, Train Loss: 0.0568, IoU Score : 0.9515, Dice Score : 0.9652, Acc : 1.0000
# Epoch 85/100, Valid Loss: 0.1353, IoU Score : 0.8051, Dice Score : 0.8600, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 86/100, Train Loss: 0.0579, IoU Score : 0.9581, Dice Score : 0.9706, Acc : 0.9985
# Epoch 86/100, Valid Loss: 0.1601, IoU Score : 0.7803, Dice Score : 0.8368, Acc : 0.9680
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 87/100, Train Loss: 0.0631, IoU Score : 0.9121, Dice Score : 0.9304, Acc : 0.9972
# Epoch 87/100, Valid Loss: 0.1514, IoU Score : 0.7815, Dice Score : 0.8374, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 88/100, Train Loss: 0.0606, IoU Score : 0.9429, Dice Score : 0.9599, Acc : 0.9978
# Epoch 88/100, Valid Loss: 0.1692, IoU Score : 0.7664, Dice Score : 0.8233, Acc : 0.9800
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 89/100, Train Loss: 0.0569, IoU Score : 0.9560, Dice Score : 0.9703, Acc : 0.9998
# Epoch 89/100, Valid Loss: 0.1430, IoU Score : 0.7825, Dice Score : 0.8370, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 90/100, Train Loss: 0.0558, IoU Score : 0.9672, Dice Score : 0.9789, Acc : 1.0000
# Epoch 90/100, Valid Loss: 0.1362, IoU Score : 0.7986, Dice Score : 0.8527, Acc : 0.9920
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 91/100, Train Loss: 0.0556, IoU Score : 0.9704, Dice Score : 0.9808, Acc : 0.9998
# Epoch 91/100, Valid Loss: 0.1384, IoU Score : 0.7927, Dice Score : 0.8472, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 92/100, Train Loss: 0.0630, IoU Score : 0.9219, Dice Score : 0.9396, Acc : 0.9972
# Epoch 92/100, Valid Loss: 0.1629, IoU Score : 0.7648, Dice Score : 0.8214, Acc : 0.9760
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 93/100, Train Loss: 0.0647, IoU Score : 0.9011, Dice Score : 0.9249, Acc : 0.9978
# Epoch 93/100, Valid Loss: 0.1325, IoU Score : 0.7802, Dice Score : 0.8366, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 94/100, Train Loss: 0.0583, IoU Score : 0.9549, Dice Score : 0.9693, Acc : 0.9985
# Epoch 94/100, Valid Loss: 0.1471, IoU Score : 0.7915, Dice Score : 0.8462, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 95/100, Train Loss: 0.0565, IoU Score : 0.9509, Dice Score : 0.9641, Acc : 1.0000
# Epoch 95/100, Valid Loss: 0.1343, IoU Score : 0.7970, Dice Score : 0.8526, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 96/100, Train Loss: 0.0603, IoU Score : 0.9519, Dice Score : 0.9660, Acc : 0.9980
# Epoch 96/100, Valid Loss: 0.1457, IoU Score : 0.7923, Dice Score : 0.8488, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 97/100, Train Loss: 0.0564, IoU Score : 0.9600, Dice Score : 0.9726, Acc : 0.9995
# Epoch 97/100, Valid Loss: 0.1583, IoU Score : 0.7936, Dice Score : 0.8483, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 98/100, Train Loss: 0.0606, IoU Score : 0.9587, Dice Score : 0.9710, Acc : 0.9965
# Epoch 98/100, Valid Loss: 0.1360, IoU Score : 0.8015, Dice Score : 0.8560, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 99/100, Train Loss: 0.0560, IoU Score : 0.9686, Dice Score : 0.9802, Acc : 1.0000
# Epoch 99/100, Valid Loss: 0.1346, IoU Score : 0.8056, Dice Score : 0.8594, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 100/100, Train Loss: 0.0552, IoU Score : 0.9762, Dice Score : 0.9863, Acc : 1.0000
# Epoch 100/100, Valid Loss: 0.1332, IoU Score : 0.8076, Dice Score : 0.8619, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------

# %%
model.eval()
masks = []

with torch.no_grad():
    fig, ax = plt.subplots(2, 3, figsize=(10, 6))
    for i in range(3):
        image = test_dataset[i][0].to(device).unsqueeze(0)
        mask = test_dataset[i][1].to(device)
        target = test_dataset[i][2]

        output_class, output_seg = model(image)
        _, pred = torch.max(output_class, 1)
        
        output_seg=torch.sigmoid(output_seg).cpu().squeeze().numpy()
        output_seg = (output_seg > 0.5).astype(np.uint8)

           # Hàng 1: ảnh pred
        ax[0, i].imshow(output_seg, cmap='gray')
        ax[0, i].set_title(f"Class: {pred.cpu().numpy()[0]}")
        ax[0, i].axis('off')
    
        # Hàng 2: mask
        ax[1, i].imshow(mask.cpu().squeeze().numpy(), cmap='gray') 
        ax[1, i].set_title(f"Class: {target}")
        ax[1, i].axis('off')
    
    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.title("Loss Score")
plt.plot(results["train_loss"], label="Train loss")
plt.plot(results["valid_loss"], label="Valid loss")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
plt.figure(figsize=(10, 5))
plt.title("IoU Score")
plt.plot(results["iou_train"], label="Train IoU")
plt.plot(results["iou_valid"], label="Valid IoU")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
plt.figure(figsize=(10, 5))
plt.title("Dice Score")
plt.plot(results["dice_train"], label="Train Dice")
plt.plot(results["dice_valid"], label="Valid Dice")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
plt.figure(figsize=(10, 5))
plt.title("Acc Score")
plt.plot(results["acc_train"], label="Train Acc")
plt.plot(results["acc_valid"], label="Valid Acc")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
true_labels = []        
pred_labels = []                
iou_total = 0
dice_total = 0
model.eval()                

with torch.no_grad():                        
    for i, (images, masks, targets) in enumerate(test_loader):
        
        images = images.to(device)
        masks = masks.to(device)
        targets = targets.to(device)
        
        output_class, output_seg = model(images)             
        _, preds = torch.max(output_class, 1)                

        # Lưu lại các giá trị thật và dự đoán                
        true_labels.extend(targets.cpu().numpy())                
        pred_labels.extend(preds.cpu().numpy())                       

        iou = calculate_iou(output_seg, masks)
        dice = calculate_dice(output_seg, masks)

        iou_total+= iou.item()
        dice_total += dice.item()

# IoU score and Dice score
print(f'IoU score : {iou_total / len(test_loader)}')
print(f'Dice score : {dice_total / len(test_loader)}')

print('------------------------------------------')
# Tạo ma trận nhầm lẫn        
cm = confusion_matrix(true_labels, pred_labels)        
disp = ConfusionMatrixDisplay(confusion_matrix=cm)        

# Hiển thị ma trận nhầm lẫn        
disp.plot(cmap=plt.cm.Blues)        
plt.title("Confusion Matrix")        
plt.show()               

print(classification_report(true_labels, pred_labels, target_names = ['glioma', 'meningioma', 'no_tumor', 'pituitary'], digits = 4))
# Out:
# IoU score : 0.8181852214038372
# Dice score : 0.8743854984641075
# ------------------------------------------
#               precision    recall  f1-score   support
#
#       glioma     1.0000    0.9706    0.9851       102
#   meningioma     0.9789    0.9858    0.9823       141
#     no_tumor     0.9914    1.0000    0.9957       115
#    pituitary     0.9930    1.0000    0.9965       142
#
#     accuracy                         0.9900       500
#    macro avg     0.9908    0.9891    0.9899       500
# weighted avg     0.9901    0.9900    0.9900       500
