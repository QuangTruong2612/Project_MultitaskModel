# %%
from PIL import Image
import torch 
import numpy as np
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms, datasets
from torchvision.transforms import ToTensor
import torch.nn.functional as F
import albumentations as A
from albumentations.pytorch import ToTensorV2
import os
from PIL import Image
import torchvision.models as models

import time
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# Set seeds
def set_seeds(seed: int=42):
    """Sets random sets for torch operations.

    Args:
        seed (int, optional): Random seed to set. Defaults to 42.
    """
    # Set the seed for general torch operations
    torch.manual_seed(seed)
    # Set the seed for CUDA torch operations (ones that happen on the GPU)
    torch.cuda.manual_seed(seed)
set_seeds()

# %% [markdown]
# # 1. Prepare Dataset

# %%
class Data_Seg_Class(Dataset):
    def __init__(self, img_class_path, img_seg_path, mask_seg_path, transform=None):
        
        self.classifi_path = img_class_path
        self.img_seg_path = img_seg_path
        self.mask_seg_path = mask_seg_path
        self.transform = transform

        name_labels = ['glioma', 'meningioma', 'no_tumor', 'pituitary']

        # lấy tất các file image trong folder classification
        self.images_filename = []
        for i in name_labels:
            for f in os.listdir(self.classifi_path + f'/{i}') :
                if os.path.isfile(os.path.join(self.classifi_path + f'/{i}', f)):
                    self.images_filename.append(os.path.splitext(f)[0])

        # Load dataset phân loại 1 lần duy nhất
        self.class_dataset = datasets.ImageFolder(self.classifi_path)
        self.label_map = {os.path.splitext(os.path.basename(p))[0]: label for p, label in self.class_dataset.samples}

    def __len__(self):
        return len(self.images_filename)

    def __getitem__(self, idx):
        filename = self.images_filename[idx]

        image_path = os.path.join(self.img_seg_path, filename + '.jpg')
        # kiểm tra file ảnh có trong folder segmentation không
        if os.path.isfile(image_path):
            
            mask_path = os.path.join(self.mask_seg_path, filename + '.png')
            
            # Đọc ảnh và mask
            image = np.array(Image.open(image_path).convert('RGB'))
            mask = np.array(Image.open(mask_path).convert('L'))
            mask = (mask > 127).astype(np.float32)
        else:
            image_path_new = os.path.join(self.classifi_path + '/no_tumor', filename + '.jpg')
            image = image = np.array(Image.open(image_path_new).convert('RGB'))
            mask = np.zeros((512, 512), dtype=np.float32)


        # Augmentation
        if self.transform:
            augmented = self.transform(image=image, mask=mask)
            image = augmented['image']
            mask = augmented['mask']
            mask = torch.unsqueeze(mask, 0)
        # Tìm label tương ứng
        label = self.label_map.get(filename, -1)  # nếu không tìm thấy thì = -1

        return image, mask, label

transform = A.Compose([
        A.Resize(256, 256),
        # A.HorizontalFlip(p=0.5),
        # A.VerticalFlip(p=0.1),
        # A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.2, rotate_limit=30, p=0.5),
        # A.RandomBrightnessContrast(brightness_limit=0.3, contrast_limit=0.3, p=0.5),
        # A.GaussNoise(var_limit=(0.01, 0.05), p=0.3),
        A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
        ToTensorV2()
    ], 
    is_check_shapes=False )

# %%
img_class_path_train = '/kaggle/input/dataset-brain/data/classification_task/train'
img_seg_path_train = '/kaggle/input/dataset-brain/data/segmentation_task/train/images'
mask_seg_path_train = '/kaggle/input/dataset-brain/data/segmentation_task/train/masks'

img_class_path_test = '/kaggle/input/dataset-brain/data/classification_task/test'
img_seg_path_test = '/kaggle/input/dataset-brain/data/segmentation_task/test/images'
mask_seg_path_test = '/kaggle/input/dataset-brain/data/segmentation_task/test/masks'

# %%
train_data = Data_Seg_Class(img_class_path_train, img_seg_path_train, mask_seg_path_train, transform)

# %%
# 1. Tìm kiếm mẫu cho mỗi class
found_samples = {}
num_classes_to_find = 4

# Duyệt qua train_data để nhặt ra mỗi class một ảnh
for i in range(len(train_data)):
    image, mask, label = train_data[i]
    
    # Xử lý nếu label là Tensor
    if isinstance(label, torch.Tensor):
        label = label.item()
    
    # Nếu class này chưa có trong danh sách tìm thấy thì thêm vào
    if label not in found_samples:
        found_samples[label] = (image, mask)
    
    # Nếu đã tìm đủ 4 class thì dừng vòng lặp cho nhanh
    if len(found_samples) == num_classes_to_find:
        break

# Sắp xếp label (0, 1, 2, 3) để hiển thị theo thứ tự
sorted_labels = sorted(found_samples.keys())
num_cols = len(sorted_labels)

# 2. Vẽ hình
if num_cols == 0:
    print("Không tìm thấy dữ liệu nào!")
else:
    # Tạo lưới plot: 2 hàng, số cột = số class tìm được
    fig, ax = plt.subplots(2, num_cols, figsize=(4 * num_cols, 6))

    for i, label in enumerate(sorted_labels):
        image, mask = found_samples[label]

        # --- Hàng 1: Ảnh gốc ---
        # Xử lý để hiển thị đúng định dạng (H, W, C)
        if isinstance(image, torch.Tensor):
            img_show = image.permute(1, 2, 0).cpu().numpy()
            
            # (Tuỳ chọn) Nếu bạn đã Normalize ảnh (trừ mean, chia std), 
            # ảnh hiển thị có thể bị tối hoặc màu lạ. 
            # Dòng dưới đây giúp đưa giá trị về khoảng [0, 1] để dễ nhìn hơn:
            img_show = (img_show - img_show.min()) / (img_show.max() - img_show.min())
        else:
            img_show = image

        # Nếu chỉ có 1 cột (1 class), ax là mảng 1 chiều, nếu nhiều cột là 2 chiều
        if num_cols > 1:
            ax_img = ax[0, i]
            ax_mask = ax[1, i]
        else:
            ax_img = ax[0]
            ax_mask = ax[1]

        ax_img.imshow(img_show)
        ax_img.set_title(f"Class: {label}")
        ax_img.axis('off')

        # --- Hàng 2: Mask ---
        if isinstance(mask, torch.Tensor):
            mask_show = mask.squeeze(0).cpu().numpy()
        else:
            mask_show = mask

        ax_mask.imshow(mask_show, cmap='gray')
        ax_mask.set_title(f"Mask - Class {label}")
        ax_mask.axis('off')

    plt.tight_layout()
    plt.show()

# %%
train_size = int(0.8 * len(train_data))
valid_test_size = len(train_data) - train_size

# Chia dữ liệu thành train (80%) và tạm thời là validation/test (20%)
train_dataset, valid_test_dataset = random_split(train_data, [train_size, valid_test_size])

# Tiếp tục chia valid_test_dataset thành validation (10%) và test (10%)
valid_size = int(0.5 * valid_test_size)
test_size = valid_test_size - valid_size
valid_dataset, test_dataset = random_split(valid_test_dataset, [valid_size, test_size])

# You can check the sizes to verify
print(f"Training set: {len(train_dataset)} samples")
print(f"Validation set: {len(valid_dataset)} samples")
print(f"Test set: {len(test_dataset)} samples")
# Out:
# Training set: 4000 samples
# Validation set: 500 samples
# Test set: 500 samples

# %%
train_loader = DataLoader(train_dataset, shuffle=True, batch_size=32)
valid_loader = DataLoader(valid_dataset, shuffle=False, batch_size=32)
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=32)

# %% [markdown]
# # 3. Load model

# %% [markdown]
# ![image.png](attachment:89883fda-0dcd-4608-8049-de56beee8da6.png)

# %%
class decode(torch.nn.Module):
    def __init__(self, in_channel, middle_channel, out_channel):
        super(decode, self).__init__()
        self.transpose = torch.nn.ConvTranspose2d(in_channel, in_channel, kernel_size=2, stride=2)
        self.conv1 = torch.nn.Conv2d(in_channel + middle_channel, out_channel,  kernel_size=3, stride=1, padding=1)
        self.bn1 = torch.nn.BatchNorm2d(out_channel)
        self.relu1 = torch.nn.ReLU()
        self.indenti1 = torch.nn.Identity()

        self.conv2 = torch.nn.Conv2d(out_channel, out_channel,  kernel_size=3, stride=1, padding=1)
        self.bn2 = torch.nn.BatchNorm2d(out_channel)
        self.relu2 = torch.nn.ReLU()
        self.indenti2 = torch.nn.Identity()


    def forward(self, x1, x2):
        x1 = self.transpose(x1)
        if x1.size() != x2.size():
            x1 = nn.functional.interpolate(x1, size=x2.shape[2:], 
                                            mode='bilinear', align_corners=False)
            
        x = torch.cat([x1, x2], dim=1)
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu1(x)
        x = self.indenti1(x)
        
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu2(x)
        x = self.indenti2(x)
      
        return x

# %%
class MultiTaskModel(nn.Module):
    def __init__(self, n_classes, n_segment, in_channels, input_size=(256,256)):
        super(MultiTaskModel, self).__init__()

        # load pretrained resnet50
        resnet = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V1)

        # encoder
        self.block_input = nn.Sequential(
            resnet.conv1,
            resnet.bn1,
            resnet.relu,
        )
        self.maxpool = resnet.maxpool

        self.encode1 = resnet.layer1
        self.encode2 = resnet.layer2
        self.encode3 = resnet.layer3
        self.encode4 = resnet.layer4

        # decoder

        self.decode1 = decode(2048, 1024, 512)
        self.decode2 = decode(512, 512, 256)
        self.decode3 = decode(256, 256, 128)
        self.decode4 = decode(128, 64, 64)       

        # output segment
        self.segmentation_head = nn.Sequential(
            nn.ConvTranspose2d(64, 32, kernel_size=2, stride=2),
            nn.ReLU(inplace=True),
            nn.Conv2d(32, n_segment, kernel_size=1)  # Output layer
        )
              # output classify
        self.classify = nn.Sequential(
            resnet.avgpool,
            nn.Flatten(),
            nn.Dropout(p=0.5),
            nn.Linear(in_features=2048,
                      out_features=n_classes,
                      bias=True)
        )

    def forward(self, inputs):
        x1 = self.block_input(inputs)
        x1_maxpool = self.maxpool(x1)
        x2 = self.encode1(x1_maxpool)
        x3 = self.encode2(x2)
        x4 = self.encode3(x3)
        x5 = self.encode4(x4)

        x6 = self.decode1(x5, x4)
        x7 = self.decode2(x6, x3)
        x8 = self.decode3(x7, x2)
        x9 = self.decode4(x8, x1)

        

        out_classify = self.classify(x5)
                
        out_segment = self.segmentation_head(x9)
        
        return out_classify, out_segment

# %%
model = MultiTaskModel(n_classes= 4, n_segment=1, in_channels=3, input_size=(256, 256))
model = model.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 180MB/s]

# %% [markdown]
# # 4. Code loss

# %%
class DiceLoss(nn.Module):
    def __init__(self, smooth=1e-6):
        super(DiceLoss, self).__init__()
        self.smooth = smooth

    def forward(self, predictions, targets):
        # 1. Chuyển logits thành xác suất
        predictions = torch.sigmoid(predictions)

        # 2. Flatten: (Batch_Size, Channel, H, W) -> (Batch_Size, -1)
        # Giữ lại chiều Batch_Size để tính riêng từng ảnh
        predictions = predictions.view(predictions.size(0), -1)
        targets = targets.view(targets.size(0), -1)

        # 3. Tính Intersection và Union cho TỪNG ảnh (dim=1)
        intersection = (predictions * targets).sum(dim=1)
        union = predictions.sum(dim=1) + targets.sum(dim=1)

        # 4. Tính Dice cho từng ảnh
        dice = (2. * intersection + self.smooth) / (union + self.smooth)

        # 5. Trả về 1 - dice trung bình của cả batch
        return 1 - dice.mean()

class CombinedLoss(nn.Module):
    def __init__(self, weight_dice=0.5, weight_bce=0.5):
        super(CombinedLoss, self).__init__()
        self.dice = DiceLoss()
        # BCEWithLogitsLoss đã tích hợp Sigmoid bên trong, rất ổn định
        self.bce = nn.BCEWithLogitsLoss() 
        self.weight_dice = weight_dice
        self.weight_bce = weight_bce

    def forward(self, predictions, targets):
        # predictions: Logits (chưa qua sigmoid)
        # targets: Binary mask (0 hoặc 1)
        
        dice_loss = self.dice(predictions, targets)
        bce_loss = self.bce(predictions, targets)
        
        return self.weight_dice * dice_loss + self.weight_bce * bce_loss

# Metrics
def calculate_iou(predictions, targets, threshold=0.5):
    predictions = torch.sigmoid(predictions)
    predictions = (predictions > threshold).float()
    
    intersection = (predictions * targets).sum(dim=(1, 2, 3))
    union = predictions.sum(dim=(1, 2, 3)) + targets.sum(dim=(1, 2, 3)) - intersection
    
    iou = (intersection + 1e-6) / (union + 1e-6)
    return iou.mean()

def calculate_dice(predictions, targets, threshold=0.5):
    predictions = torch.sigmoid(predictions)
    predictions = (predictions > threshold).float()
    
    intersection = (predictions * targets).sum(dim=(1, 2, 3))
    dice = (2. * intersection + 1e-6) / (predictions.sum(dim=(1, 2, 3)) + targets.sum(dim=(1, 2, 3)) + 1e-6)
    return dice.mean()

# %%
class SimpleMultiTaskLoss(nn.Module):
    """
    Hàm loss đơn giản với trọng số cố định (Fixed Weight).
    """
    def __init__(self, weight_seg=0.5, weight_cls=0.5):
        super(SimpleMultiTaskLoss, self).__init__()
        # Loss cho Segmentation (đã có từ cell 14)
        self.loss_seg = CombinedLoss() 
        # Loss cho Classification
        self.loss_classify = nn.CrossEntropyLoss()
        
        self.weight_seg = weight_seg
        self.weight_cls = weight_cls
        
    def forward(self, seg_logits, seg_labels, classify_logits, classify_labels):
        # Tính loss riêng lẻ
        loss_seg = self.loss_seg(seg_logits, seg_labels)
        loss_classify = self.loss_classify(classify_logits, classify_labels)
        
        # Cộng loss theo trọng số cố định
        total_loss = (self.weight_seg * loss_seg) + (self.weight_cls * loss_classify)
        
        return total_loss

# %% [markdown]
# # 5. Train model

# %%
def train(model, criterion, optimizer, train_loader, device):
    model.train()
    total_loss = 0
    corrects = 0
    total_iou = 0
    total_dice = 0
    for i, (images, masks, targets) in enumerate(train_loader):
        optimizer.zero_grad()

        images = images.to(device)
        masks = masks.to(device)
        targets = targets.to(device)
        
        output_class, output_seg = model(images)
        
        loss = criterion(output_seg, masks, output_class, targets)

        _, pred = torch.max(output_class, 1)
        corrects += torch.sum(targets == pred).item()

        loss.backward()
        optimizer.step()

        with torch.no_grad():
            iou = calculate_iou(output_seg, masks)
            dice = calculate_dice(output_seg, masks)
        
        total_loss += loss.item()
        total_iou += iou.item()
        total_dice += dice.item()
    return total_loss / len(train_loader), total_iou/len(train_loader), total_dice/len(train_loader), corrects/len(train_loader.dataset)
def valid(model, criterion, valid_loader, device):
    model.eval()
    with torch.no_grad():
        total_loss = 0
        corrects = 0
        total_iou = 0
        total_dice = 0
        for i, (images, masks, targets) in enumerate(valid_loader):
            images = images.to(device)
            masks = masks.to(device)
            targets = targets.to(device)
    
            output_class, output_seg = model(images)
            loss =criterion(output_seg, masks, output_class, targets)
    
            _, pred = torch.max(output_class, 1)
            corrects += torch.sum(targets == pred).item()
            
            iou = calculate_iou(output_seg, masks)
            dice = calculate_dice(output_seg, masks)
            
            total_loss += loss.item()
            total_iou += iou.item()
            total_dice += dice.item()
    return total_loss / len(valid_loader), total_iou/len(valid_loader), total_dice/len(valid_loader), corrects/len(valid_loader.dataset)

# %%
results = {
    "train_loss" : [],
    "iou_train"  : [],
    "dice_train" : [],
    "acc_train"  : [],
    "valid_loss" : [],
    "iou_valid"  : [],
    "dice_valid" : [],
    "acc_valid"  : []
    }
# configure
criterion = SimpleMultiTaskLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)
epochs = 100
for epoch in range(epochs):
    train_loss, iou_train, dice_train, acc_train = train(model, criterion, optimizer, train_loader, device)
    valid_loss, iou_valid, dice_valid, acc_valid = valid(model, criterion, valid_loader, device)
    
    print(f'Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, IoU Score : {iou_train:.4f}, Dice Score : {dice_train:.4f}, Acc : {acc_train:.4f}')
    print(f'Epoch {epoch+1}/{epochs}, Valid Loss: {valid_loss:.4f}, IoU Score : {iou_valid:.4f}, Dice Score : {dice_valid:.4f}, Acc : {acc_valid:.4f}')
    print('-------------------------------------------------------------------------------------------------------------------------------')

    results["train_loss"].append(train_loss)
    results["iou_train"].append(iou_train)
    results["dice_train"].append(dice_train)
    results["acc_train"].append(acc_train)
    results["valid_loss"].append(valid_loss)
    results["iou_valid"].append(iou_valid)
    results["dice_valid"].append(dice_valid)
    results["acc_valid"].append(acc_valid)
# Out:
# Epoch 1/100, Train Loss: 0.4782, IoU Score : 0.1773, Dice Score : 0.1778, Acc : 0.9105
# Epoch 1/100, Valid Loss: 0.3577, IoU Score : 0.2492, Dice Score : 0.2492, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 2/100, Train Loss: 0.3153, IoU Score : 0.2070, Dice Score : 0.2070, Acc : 0.9810
# Epoch 2/100, Valid Loss: 0.3293, IoU Score : 0.2492, Dice Score : 0.2492, Acc : 0.9740
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 3/100, Train Loss: 0.2538, IoU Score : 0.2070, Dice Score : 0.2070, Acc : 0.9912
# Epoch 3/100, Valid Loss: 0.2393, IoU Score : 0.2492, Dice Score : 0.2492, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 4/100, Train Loss: 0.2060, IoU Score : 0.2070, Dice Score : 0.2070, Acc : 0.9928
# Epoch 4/100, Valid Loss: 0.2037, IoU Score : 0.2492, Dice Score : 0.2492, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 5/100, Train Loss: 0.1743, IoU Score : 0.2070, Dice Score : 0.2070, Acc : 0.9962
# Epoch 5/100, Valid Loss: 0.1875, IoU Score : 0.2492, Dice Score : 0.2492, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 6/100, Train Loss: 0.1661, IoU Score : 0.2070, Dice Score : 0.2070, Acc : 0.9938
# Epoch 6/100, Valid Loss: 0.2204, IoU Score : 0.2492, Dice Score : 0.2492, Acc : 0.9620
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 7/100, Train Loss: 0.1603, IoU Score : 0.2070, Dice Score : 0.2070, Acc : 0.9950
# Epoch 7/100, Valid Loss: 0.1704, IoU Score : 0.2492, Dice Score : 0.2492, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 8/100, Train Loss: 0.1473, IoU Score : 0.3854, Dice Score : 0.4050, Acc : 0.9965
# Epoch 8/100, Valid Loss: 0.1730, IoU Score : 0.7986, Dice Score : 0.8654, Acc : 0.9760
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 9/100, Train Loss: 0.1425, IoU Score : 0.8114, Dice Score : 0.8770, Acc : 0.9972
# Epoch 9/100, Valid Loss: 0.1730, IoU Score : 0.8067, Dice Score : 0.8706, Acc : 0.9780
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 10/100, Train Loss: 0.1369, IoU Score : 0.8247, Dice Score : 0.8874, Acc : 0.9980
# Epoch 10/100, Valid Loss: 0.1704, IoU Score : 0.8056, Dice Score : 0.8685, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 11/100, Train Loss: 0.1329, IoU Score : 0.8313, Dice Score : 0.8915, Acc : 0.9988
# Epoch 11/100, Valid Loss: 0.1743, IoU Score : 0.7881, Dice Score : 0.8502, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 12/100, Train Loss: 0.1400, IoU Score : 0.8262, Dice Score : 0.8871, Acc : 0.9940
# Epoch 12/100, Valid Loss: 0.1688, IoU Score : 0.7924, Dice Score : 0.8539, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 13/100, Train Loss: 0.1364, IoU Score : 0.8310, Dice Score : 0.8917, Acc : 0.9948
# Epoch 13/100, Valid Loss: 0.2490, IoU Score : 0.7651, Dice Score : 0.8294, Acc : 0.9340
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 14/100, Train Loss: 0.1328, IoU Score : 0.8274, Dice Score : 0.8886, Acc : 0.9955
# Epoch 14/100, Valid Loss: 0.1568, IoU Score : 0.8081, Dice Score : 0.8710, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 15/100, Train Loss: 0.1219, IoU Score : 0.8481, Dice Score : 0.9060, Acc : 1.0000
# Epoch 15/100, Valid Loss: 0.1541, IoU Score : 0.8032, Dice Score : 0.8642, Acc : 0.9940
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 16/100, Train Loss: 0.1179, IoU Score : 0.8613, Dice Score : 0.9156, Acc : 1.0000
# Epoch 16/100, Valid Loss: 0.1464, IoU Score : 0.8088, Dice Score : 0.8706, Acc : 0.9940
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 17/100, Train Loss: 0.1182, IoU Score : 0.8720, Dice Score : 0.9234, Acc : 0.9972
# Epoch 17/100, Valid Loss: 0.2049, IoU Score : 0.8100, Dice Score : 0.8724, Acc : 0.9760
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 18/100, Train Loss: 0.1239, IoU Score : 0.8445, Dice Score : 0.8987, Acc : 0.9930
# Epoch 18/100, Valid Loss: 0.1625, IoU Score : 0.7880, Dice Score : 0.8525, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 19/100, Train Loss: 0.1134, IoU Score : 0.8631, Dice Score : 0.9150, Acc : 0.9990
# Epoch 19/100, Valid Loss: 0.1511, IoU Score : 0.8223, Dice Score : 0.8806, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 20/100, Train Loss: 0.1140, IoU Score : 0.8680, Dice Score : 0.9179, Acc : 0.9978
# Epoch 20/100, Valid Loss: 0.1495, IoU Score : 0.7761, Dice Score : 0.8354, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 21/100, Train Loss: 0.1078, IoU Score : 0.8727, Dice Score : 0.9194, Acc : 0.9980
# Epoch 21/100, Valid Loss: 0.1514, IoU Score : 0.8327, Dice Score : 0.8907, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 22/100, Train Loss: 0.1101, IoU Score : 0.8623, Dice Score : 0.9072, Acc : 0.9958
# Epoch 22/100, Valid Loss: 0.2083, IoU Score : 0.8018, Dice Score : 0.8593, Acc : 0.9600
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 23/100, Train Loss: 0.1045, IoU Score : 0.8754, Dice Score : 0.9191, Acc : 0.9975
# Epoch 23/100, Valid Loss: 0.1446, IoU Score : 0.8078, Dice Score : 0.8659, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 24/100, Train Loss: 0.0989, IoU Score : 0.8765, Dice Score : 0.9204, Acc : 0.9972
# Epoch 24/100, Valid Loss: 0.1257, IoU Score : 0.8195, Dice Score : 0.8753, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 25/100, Train Loss: 0.0703, IoU Score : 0.8907, Dice Score : 0.9332, Acc : 0.9995
# Epoch 25/100, Valid Loss: 0.1270, IoU Score : 0.8256, Dice Score : 0.8810, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 26/100, Train Loss: 0.0688, IoU Score : 0.8954, Dice Score : 0.9358, Acc : 0.9990
# Epoch 26/100, Valid Loss: 0.1217, IoU Score : 0.8238, Dice Score : 0.8794, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 27/100, Train Loss: 0.0678, IoU Score : 0.9073, Dice Score : 0.9440, Acc : 0.9988
# Epoch 27/100, Valid Loss: 0.1229, IoU Score : 0.8227, Dice Score : 0.8775, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 28/100, Train Loss: 0.0677, IoU Score : 0.8976, Dice Score : 0.9346, Acc : 0.9988
# Epoch 28/100, Valid Loss: 0.1205, IoU Score : 0.8118, Dice Score : 0.8696, Acc : 0.9920
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 29/100, Train Loss: 0.0662, IoU Score : 0.9000, Dice Score : 0.9363, Acc : 0.9995
# Epoch 29/100, Valid Loss: 0.1139, IoU Score : 0.8299, Dice Score : 0.8848, Acc : 0.9940
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 30/100, Train Loss: 0.0650, IoU Score : 0.9057, Dice Score : 0.9401, Acc : 0.9995
# Epoch 30/100, Valid Loss: 0.1176, IoU Score : 0.8133, Dice Score : 0.8691, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 31/100, Train Loss: 0.0635, IoU Score : 0.9167, Dice Score : 0.9484, Acc : 0.9998
# Epoch 31/100, Valid Loss: 0.1281, IoU Score : 0.8354, Dice Score : 0.8906, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 32/100, Train Loss: 0.0694, IoU Score : 0.9219, Dice Score : 0.9530, Acc : 0.9948
# Epoch 32/100, Valid Loss: 0.2848, IoU Score : 0.7932, Dice Score : 0.8493, Acc : 0.9080
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 33/100, Train Loss: 0.0794, IoU Score : 0.8310, Dice Score : 0.8738, Acc : 0.9950
# Epoch 33/100, Valid Loss: 0.1322, IoU Score : 0.7848, Dice Score : 0.8426, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 34/100, Train Loss: 0.0728, IoU Score : 0.8654, Dice Score : 0.9027, Acc : 0.9975
# Epoch 34/100, Valid Loss: 0.1282, IoU Score : 0.7920, Dice Score : 0.8478, Acc : 0.9780
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 35/100, Train Loss: 0.0717, IoU Score : 0.9035, Dice Score : 0.9370, Acc : 0.9952
# Epoch 35/100, Valid Loss: 0.1275, IoU Score : 0.8223, Dice Score : 0.8773, Acc : 0.9800
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 36/100, Train Loss: 0.0670, IoU Score : 0.9113, Dice Score : 0.9424, Acc : 0.9978
# Epoch 36/100, Valid Loss: 0.1214, IoU Score : 0.7828, Dice Score : 0.8381, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 37/100, Train Loss: 0.0620, IoU Score : 0.9234, Dice Score : 0.9515, Acc : 0.9998
# Epoch 37/100, Valid Loss: 0.1120, IoU Score : 0.8312, Dice Score : 0.8847, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 38/100, Train Loss: 0.0610, IoU Score : 0.9371, Dice Score : 0.9629, Acc : 0.9998
# Epoch 38/100, Valid Loss: 0.1100, IoU Score : 0.8234, Dice Score : 0.8774, Acc : 0.9940
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 39/100, Train Loss: 0.0638, IoU Score : 0.9284, Dice Score : 0.9538, Acc : 0.9995
# Epoch 39/100, Valid Loss: 0.1135, IoU Score : 0.8230, Dice Score : 0.8778, Acc : 0.9940
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 40/100, Train Loss: 0.0602, IoU Score : 0.9339, Dice Score : 0.9582, Acc : 1.0000
# Epoch 40/100, Valid Loss: 0.1117, IoU Score : 0.8229, Dice Score : 0.8764, Acc : 0.9920
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 41/100, Train Loss: 0.0601, IoU Score : 0.9385, Dice Score : 0.9616, Acc : 0.9998
# Epoch 41/100, Valid Loss: 0.1130, IoU Score : 0.8206, Dice Score : 0.8747, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 42/100, Train Loss: 0.0595, IoU Score : 0.9388, Dice Score : 0.9610, Acc : 1.0000
# Epoch 42/100, Valid Loss: 0.1122, IoU Score : 0.8209, Dice Score : 0.8750, Acc : 0.9920
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 43/100, Train Loss: 0.0592, IoU Score : 0.9355, Dice Score : 0.9571, Acc : 1.0000
# Epoch 43/100, Valid Loss: 0.1126, IoU Score : 0.8170, Dice Score : 0.8710, Acc : 0.9920
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 44/100, Train Loss: 0.0590, IoU Score : 0.9383, Dice Score : 0.9593, Acc : 1.0000
# Epoch 44/100, Valid Loss: 0.1141, IoU Score : 0.8199, Dice Score : 0.8738, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 45/100, Train Loss: 0.0587, IoU Score : 0.9364, Dice Score : 0.9567, Acc : 1.0000
# Epoch 45/100, Valid Loss: 0.1121, IoU Score : 0.7916, Dice Score : 0.8464, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 46/100, Train Loss: 0.0586, IoU Score : 0.9422, Dice Score : 0.9623, Acc : 1.0000
# Epoch 46/100, Valid Loss: 0.1165, IoU Score : 0.8167, Dice Score : 0.8707, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 47/100, Train Loss: 0.0584, IoU Score : 0.9431, Dice Score : 0.9626, Acc : 1.0000
# Epoch 47/100, Valid Loss: 0.1144, IoU Score : 0.8078, Dice Score : 0.8622, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 48/100, Train Loss: 0.0582, IoU Score : 0.9416, Dice Score : 0.9608, Acc : 1.0000
# Epoch 48/100, Valid Loss: 0.1130, IoU Score : 0.8187, Dice Score : 0.8729, Acc : 0.9920
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 49/100, Train Loss: 0.0581, IoU Score : 0.9472, Dice Score : 0.9658, Acc : 1.0000
# Epoch 49/100, Valid Loss: 0.1131, IoU Score : 0.7208, Dice Score : 0.7753, Acc : 0.9920
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 50/100, Train Loss: 0.0579, IoU Score : 0.9429, Dice Score : 0.9612, Acc : 1.0000
# Epoch 50/100, Valid Loss: 0.1138, IoU Score : 0.8021, Dice Score : 0.8559, Acc : 0.9920
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 51/100, Train Loss: 0.0577, IoU Score : 0.9464, Dice Score : 0.9640, Acc : 1.0000
# Epoch 51/100, Valid Loss: 0.1182, IoU Score : 0.8136, Dice Score : 0.8681, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 52/100, Train Loss: 0.0576, IoU Score : 0.9442, Dice Score : 0.9616, Acc : 1.0000
# Epoch 52/100, Valid Loss: 0.1168, IoU Score : 0.8005, Dice Score : 0.8554, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 53/100, Train Loss: 0.0575, IoU Score : 0.9495, Dice Score : 0.9665, Acc : 1.0000
# Epoch 53/100, Valid Loss: 0.1165, IoU Score : 0.8260, Dice Score : 0.8806, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 54/100, Train Loss: 0.0574, IoU Score : 0.9462, Dice Score : 0.9632, Acc : 1.0000
# Epoch 54/100, Valid Loss: 0.1158, IoU Score : 0.8058, Dice Score : 0.8603, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 55/100, Train Loss: 0.0575, IoU Score : 0.9429, Dice Score : 0.9598, Acc : 1.0000
# Epoch 55/100, Valid Loss: 0.1216, IoU Score : 0.7694, Dice Score : 0.8241, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 56/100, Train Loss: 0.1134, IoU Score : 0.7711, Dice Score : 0.8173, Acc : 0.9740
# Epoch 56/100, Valid Loss: 0.2014, IoU Score : 0.6439, Dice Score : 0.7063, Acc : 0.9380
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 57/100, Train Loss: 0.0771, IoU Score : 0.8674, Dice Score : 0.9067, Acc : 0.9938
# Epoch 57/100, Valid Loss: 0.1386, IoU Score : 0.7755, Dice Score : 0.8299, Acc : 0.9800
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 58/100, Train Loss: 0.0635, IoU Score : 0.9079, Dice Score : 0.9358, Acc : 0.9985
# Epoch 58/100, Valid Loss: 0.1216, IoU Score : 0.7870, Dice Score : 0.8421, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 59/100, Train Loss: 0.0595, IoU Score : 0.9265, Dice Score : 0.9485, Acc : 1.0000
# Epoch 59/100, Valid Loss: 0.1226, IoU Score : 0.8012, Dice Score : 0.8559, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 60/100, Train Loss: 0.0581, IoU Score : 0.9385, Dice Score : 0.9570, Acc : 1.0000
# Epoch 60/100, Valid Loss: 0.1240, IoU Score : 0.7869, Dice Score : 0.8423, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 61/100, Train Loss: 0.0579, IoU Score : 0.9396, Dice Score : 0.9567, Acc : 1.0000
# Epoch 61/100, Valid Loss: 0.1284, IoU Score : 0.8122, Dice Score : 0.8676, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 62/100, Train Loss: 0.0589, IoU Score : 0.9444, Dice Score : 0.9613, Acc : 0.9995
# Epoch 62/100, Valid Loss: 0.1342, IoU Score : 0.7850, Dice Score : 0.8408, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 63/100, Train Loss: 0.0575, IoU Score : 0.9423, Dice Score : 0.9587, Acc : 1.0000
# Epoch 63/100, Valid Loss: 0.1281, IoU Score : 0.7908, Dice Score : 0.8475, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 64/100, Train Loss: 0.0568, IoU Score : 0.9557, Dice Score : 0.9707, Acc : 1.0000
# Epoch 64/100, Valid Loss: 0.1287, IoU Score : 0.8073, Dice Score : 0.8630, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 65/100, Train Loss: 0.0567, IoU Score : 0.9566, Dice Score : 0.9708, Acc : 1.0000
# Epoch 65/100, Valid Loss: 0.1273, IoU Score : 0.7940, Dice Score : 0.8502, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 66/100, Train Loss: 0.0565, IoU Score : 0.9571, Dice Score : 0.9711, Acc : 1.0000
# Epoch 66/100, Valid Loss: 0.1288, IoU Score : 0.7972, Dice Score : 0.8533, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 67/100, Train Loss: 0.0567, IoU Score : 0.9483, Dice Score : 0.9629, Acc : 1.0000
# Epoch 67/100, Valid Loss: 0.1283, IoU Score : 0.8037, Dice Score : 0.8598, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 68/100, Train Loss: 0.0564, IoU Score : 0.9592, Dice Score : 0.9729, Acc : 1.0000
# Epoch 68/100, Valid Loss: 0.1273, IoU Score : 0.7986, Dice Score : 0.8543, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 69/100, Train Loss: 0.0561, IoU Score : 0.9602, Dice Score : 0.9733, Acc : 1.0000
# Epoch 69/100, Valid Loss: 0.1256, IoU Score : 0.7947, Dice Score : 0.8506, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 70/100, Train Loss: 0.0561, IoU Score : 0.9623, Dice Score : 0.9751, Acc : 1.0000
# Epoch 70/100, Valid Loss: 0.1279, IoU Score : 0.8085, Dice Score : 0.8646, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 71/100, Train Loss: 0.0902, IoU Score : 0.8464, Dice Score : 0.8817, Acc : 0.9842
# Epoch 71/100, Valid Loss: 0.1780, IoU Score : 0.6480, Dice Score : 0.7069, Acc : 0.9560
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 72/100, Train Loss: 0.0731, IoU Score : 0.8669, Dice Score : 0.9006, Acc : 0.9970
# Epoch 72/100, Valid Loss: 0.1304, IoU Score : 0.7360, Dice Score : 0.7943, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 73/100, Train Loss: 0.0599, IoU Score : 0.9166, Dice Score : 0.9392, Acc : 1.0000
# Epoch 73/100, Valid Loss: 0.1361, IoU Score : 0.7798, Dice Score : 0.8360, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 74/100, Train Loss: 0.0578, IoU Score : 0.9439, Dice Score : 0.9611, Acc : 0.9998
# Epoch 74/100, Valid Loss: 0.1288, IoU Score : 0.7663, Dice Score : 0.8230, Acc : 0.9800
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 75/100, Train Loss: 0.0575, IoU Score : 0.9446, Dice Score : 0.9601, Acc : 0.9998
# Epoch 75/100, Valid Loss: 0.1275, IoU Score : 0.8016, Dice Score : 0.8571, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 76/100, Train Loss: 0.0638, IoU Score : 0.9348, Dice Score : 0.9523, Acc : 0.9980
# Epoch 76/100, Valid Loss: 0.1383, IoU Score : 0.7192, Dice Score : 0.7757, Acc : 0.9800
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 77/100, Train Loss: 0.0576, IoU Score : 0.9479, Dice Score : 0.9639, Acc : 1.0000
# Epoch 77/100, Valid Loss: 0.1282, IoU Score : 0.7841, Dice Score : 0.8408, Acc : 0.9800
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 78/100, Train Loss: 0.0567, IoU Score : 0.9536, Dice Score : 0.9678, Acc : 1.0000
# Epoch 78/100, Valid Loss: 0.1318, IoU Score : 0.7919, Dice Score : 0.8476, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 79/100, Train Loss: 0.0573, IoU Score : 0.9480, Dice Score : 0.9613, Acc : 0.9992
# Epoch 79/100, Valid Loss: 0.1474, IoU Score : 0.7645, Dice Score : 0.8220, Acc : 0.9760
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 80/100, Train Loss: 0.0594, IoU Score : 0.9337, Dice Score : 0.9486, Acc : 0.9982
# Epoch 80/100, Valid Loss: 0.1663, IoU Score : 0.7809, Dice Score : 0.8379, Acc : 0.9740
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 81/100, Train Loss: 0.0578, IoU Score : 0.9509, Dice Score : 0.9654, Acc : 0.9995
# Epoch 81/100, Valid Loss: 0.1571, IoU Score : 0.7342, Dice Score : 0.7923, Acc : 0.9780
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 82/100, Train Loss: 0.0566, IoU Score : 0.9522, Dice Score : 0.9659, Acc : 0.9998
# Epoch 82/100, Valid Loss: 0.1502, IoU Score : 0.8061, Dice Score : 0.8633, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 83/100, Train Loss: 0.0559, IoU Score : 0.9680, Dice Score : 0.9801, Acc : 1.0000
# Epoch 83/100, Valid Loss: 0.1442, IoU Score : 0.8159, Dice Score : 0.8727, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 84/100, Train Loss: 0.0559, IoU Score : 0.9674, Dice Score : 0.9788, Acc : 0.9998
# Epoch 84/100, Valid Loss: 0.1604, IoU Score : 0.7954, Dice Score : 0.8512, Acc : 0.9760
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 85/100, Train Loss: 0.0597, IoU Score : 0.9463, Dice Score : 0.9609, Acc : 0.9972
# Epoch 85/100, Valid Loss: 0.2008, IoU Score : 0.7539, Dice Score : 0.8108, Acc : 0.9620
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 86/100, Train Loss: 0.0649, IoU Score : 0.9049, Dice Score : 0.9285, Acc : 0.9960
# Epoch 86/100, Valid Loss: 0.1277, IoU Score : 0.8061, Dice Score : 0.8626, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 87/100, Train Loss: 0.0683, IoU Score : 0.8979, Dice Score : 0.9227, Acc : 0.9945
# Epoch 87/100, Valid Loss: 0.1416, IoU Score : 0.7633, Dice Score : 0.8194, Acc : 0.9780
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 88/100, Train Loss: 0.0596, IoU Score : 0.9332, Dice Score : 0.9527, Acc : 0.9992
# Epoch 88/100, Valid Loss: 0.1307, IoU Score : 0.7562, Dice Score : 0.8135, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 89/100, Train Loss: 0.0569, IoU Score : 0.9524, Dice Score : 0.9675, Acc : 1.0000
# Epoch 89/100, Valid Loss: 0.1315, IoU Score : 0.8013, Dice Score : 0.8564, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 90/100, Train Loss: 0.0561, IoU Score : 0.9588, Dice Score : 0.9717, Acc : 1.0000
# Epoch 90/100, Valid Loss: 0.1319, IoU Score : 0.7986, Dice Score : 0.8541, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 91/100, Train Loss: 0.0556, IoU Score : 0.9700, Dice Score : 0.9814, Acc : 1.0000
# Epoch 91/100, Valid Loss: 0.1321, IoU Score : 0.8091, Dice Score : 0.8644, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 92/100, Train Loss: 0.0554, IoU Score : 0.9714, Dice Score : 0.9819, Acc : 1.0000
# Epoch 92/100, Valid Loss: 0.1334, IoU Score : 0.8112, Dice Score : 0.8663, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 93/100, Train Loss: 0.0552, IoU Score : 0.9736, Dice Score : 0.9836, Acc : 1.0000
# Epoch 93/100, Valid Loss: 0.1327, IoU Score : 0.8135, Dice Score : 0.8687, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 94/100, Train Loss: 0.0550, IoU Score : 0.9767, Dice Score : 0.9863, Acc : 1.0000
# Epoch 94/100, Valid Loss: 0.1348, IoU Score : 0.8136, Dice Score : 0.8693, Acc : 0.9800
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 95/100, Train Loss: 0.0549, IoU Score : 0.9775, Dice Score : 0.9869, Acc : 1.0000
# Epoch 95/100, Valid Loss: 0.1329, IoU Score : 0.8118, Dice Score : 0.8674, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 96/100, Train Loss: 0.0549, IoU Score : 0.9786, Dice Score : 0.9876, Acc : 1.0000
# Epoch 96/100, Valid Loss: 0.1325, IoU Score : 0.8182, Dice Score : 0.8742, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 97/100, Train Loss: 0.0548, IoU Score : 0.9786, Dice Score : 0.9877, Acc : 1.0000
# Epoch 97/100, Valid Loss: 0.1350, IoU Score : 0.8154, Dice Score : 0.8712, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 98/100, Train Loss: 0.0382, IoU Score : 0.9484, Dice Score : 0.9711, Acc : 1.0000
# Epoch 98/100, Valid Loss: 0.1063, IoU Score : 0.8087, Dice Score : 0.8688, Acc : 0.9740
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 99/100, Train Loss: 0.0235, IoU Score : 0.8941, Dice Score : 0.9373, Acc : 0.9980
# Epoch 99/100, Valid Loss: 0.0958, IoU Score : 0.8201, Dice Score : 0.8764, Acc : 0.9800
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 100/100, Train Loss: 0.0127, IoU Score : 0.9309, Dice Score : 0.9621, Acc : 0.9992
# Epoch 100/100, Valid Loss: 0.0892, IoU Score : 0.8156, Dice Score : 0.8716, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------

# %%
model.eval()
masks = []

with torch.no_grad():
    fig, ax = plt.subplots(2, 3, figsize=(10, 6))
    for i in range(3):
        image = test_dataset[i][0].to(device).unsqueeze(0)
        mask = test_dataset[i][1].to(device)
        target = test_dataset[i][2]

        output_class, output_seg = model(image)
        _, pred = torch.max(output_class, 1)
        
        output_seg=torch.sigmoid(output_seg).cpu().squeeze().numpy()
        output_seg = (output_seg > 0.5).astype(np.uint8)

           # Hàng 1: ảnh pred
        ax[0, i].imshow(output_seg, cmap='gray')
        ax[0, i].set_title(f"Class: {pred.cpu().numpy()[0]}")
        ax[0, i].axis('off')
    
        # Hàng 2: mask
        ax[1, i].imshow(mask.cpu().squeeze().numpy(), cmap='gray') 
        ax[1, i].set_title(f"Class: {target}")
        ax[1, i].axis('off')
    
    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.title("Loss Score")
plt.plot(results["train_loss"], label="Train loss")
plt.plot(results["valid_loss"], label="Valid loss")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
plt.figure(figsize=(10, 5))
plt.title("IoU Score")
plt.plot(results["iou_train"], label="Train IoU")
plt.plot(results["iou_valid"], label="Valid IoU")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
plt.figure(figsize=(10, 5))
plt.title("Dice Score")
plt.plot(results["dice_train"], label="Train Dice")
plt.plot(results["dice_valid"], label="Valid Dice")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
plt.figure(figsize=(10, 5))
plt.title("Acc Score")
plt.plot(results["acc_train"], label="Train Acc")
plt.plot(results["acc_valid"], label="Valid Acc")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
true_labels = []        
pred_labels = []                
iou_total = 0
dice_total = 0
model.eval()                

with torch.no_grad():                        
    for i, (images, masks, targets) in enumerate(test_loader):
        
        images = images.to(device)
        masks = masks.to(device)
        targets = targets.to(device)
        
        output_class, output_seg = model(images)             
        _, preds = torch.max(output_class, 1)                

        # Lưu lại các giá trị thật và dự đoán                
        true_labels.extend(targets.cpu().numpy())                
        pred_labels.extend(preds.cpu().numpy())                       

        iou = calculate_iou(output_seg, masks)
        dice = calculate_dice(output_seg, masks)

        iou_total+= iou.item()
        dice_total += dice.item()

# IoU score and Dice score
print(f'IoU score : {iou_total / len(test_loader)}')
print(f'Dice score : {dice_total / len(test_loader)}')

print('------------------------------------------')
# Tạo ma trận nhầm lẫn        
cm = confusion_matrix(true_labels, pred_labels)        
disp = ConfusionMatrixDisplay(confusion_matrix=cm)        

# Hiển thị ma trận nhầm lẫn        
disp.plot(cmap=plt.cm.Blues)        
plt.title("Confusion Matrix")        
plt.show()               

print(classification_report(true_labels, pred_labels, target_names = ['glioma', 'meningioma', 'no_tumor', 'pituitary'], digits = 4))
# Out:
# IoU score : 0.8152547106146812
# Dice score : 0.8730791471898556
# ------------------------------------------
#               precision    recall  f1-score   support
#
#       glioma     1.0000    0.9706    0.9851       102
#   meningioma     0.9787    0.9787    0.9787       141
#     no_tumor     0.9829    1.0000    0.9914       115
#    pituitary     0.9930    1.0000    0.9965       142
#
#     accuracy                         0.9880       500
#    macro avg     0.9887    0.9873    0.9879       500
# weighted avg     0.9881    0.9880    0.9880       500
