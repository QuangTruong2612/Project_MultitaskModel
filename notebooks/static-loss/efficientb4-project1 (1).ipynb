# %%
from PIL import Image
import torch 
import numpy as np
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms, datasets
from torchvision.transforms import ToTensor
import torch.nn.functional as F
import albumentations as A
from albumentations.pytorch import ToTensorV2
import os
from PIL import Image
import torchvision.models as models

import time
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# Set seeds
def set_seeds(seed: int=42):
    """Sets random sets for torch operations.

    Args:
        seed (int, optional): Random seed to set. Defaults to 42.
    """
    # Set the seed for general torch operations
    torch.manual_seed(seed)
    # Set the seed for CUDA torch operations (ones that happen on the GPU)
    torch.cuda.manual_seed(seed)
set_seeds()

# %% [markdown]
# # 1. Prepare Dataset

# %%
class Data_Seg_Class(Dataset):
    def __init__(self, img_class_path, img_seg_path, mask_seg_path, transform=None):
        
        self.classifi_path = img_class_path
        self.img_seg_path = img_seg_path
        self.mask_seg_path = mask_seg_path
        self.transform = transform

        name_labels = ['glioma', 'meningioma', 'no_tumor', 'pituitary']

        # lấy tất các file image trong folder classification
        self.images_filename = []
        for i in name_labels:
            for f in os.listdir(self.classifi_path + f'/{i}') :
                if os.path.isfile(os.path.join(self.classifi_path + f'/{i}', f)):
                    self.images_filename.append(os.path.splitext(f)[0])

        # Load dataset phân loại 1 lần duy nhất
        self.class_dataset = datasets.ImageFolder(self.classifi_path)
        self.label_map = {os.path.splitext(os.path.basename(p))[0]: label for p, label in self.class_dataset.samples}

    def __len__(self):
        return len(self.images_filename)

    def __getitem__(self, idx):
        filename = self.images_filename[idx]

        image_path = os.path.join(self.img_seg_path, filename + '.jpg')
        # kiểm tra file ảnh có trong folder segmentation không
        if os.path.isfile(image_path):
            
            mask_path = os.path.join(self.mask_seg_path, filename + '.png')
            
            # Đọc ảnh và mask
            image = np.array(Image.open(image_path).convert('RGB'))
            mask = np.array(Image.open(mask_path).convert('L'))
            mask = (mask > 127).astype(np.float32)
        else:
            image_path_new = os.path.join(self.classifi_path + '/no_tumor', filename + '.jpg')
            image = image = np.array(Image.open(image_path_new).convert('RGB'))
            mask = np.zeros((512, 512), dtype=np.float32)


        # Augmentation
        if self.transform:
            augmented = self.transform(image=image, mask=mask)
            image = augmented['image']
            mask = augmented['mask']
            mask = torch.unsqueeze(mask, 0)
        # Tìm label tương ứng
        label = self.label_map.get(filename, -1)  # nếu không tìm thấy thì = -1

        return image, mask, label

transform = A.Compose([
        A.Resize(256, 256),
        # A.HorizontalFlip(p=0.5),
        # A.VerticalFlip(p=0.1),
        # A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.2, rotate_limit=30, p=0.5),
        # A.RandomBrightnessContrast(brightness_limit=0.3, contrast_limit=0.3, p=0.5),
        # A.GaussNoise(var_limit=(0.01, 0.05), p=0.3),
        A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
        ToTensorV2()
    ], 
    is_check_shapes=False )

# %%
img_class_path_train = '/kaggle/input/dataset-brain/data/classification_task/train'
img_seg_path_train = '/kaggle/input/dataset-brain/data/segmentation_task/train/images'
mask_seg_path_train = '/kaggle/input/dataset-brain/data/segmentation_task/train/masks'

img_class_path_test = '/kaggle/input/dataset-brain/data/classification_task/test'
img_seg_path_test = '/kaggle/input/dataset-brain/data/segmentation_task/test/images'
mask_seg_path_test = '/kaggle/input/dataset-brain/data/segmentation_task/test/masks'

# %%
train_data = Data_Seg_Class(img_class_path_train, img_seg_path_train, mask_seg_path_train, transform)

# %%
# 1. Tìm kiếm mẫu cho mỗi class
found_samples = {}
num_classes_to_find = 4

# Duyệt qua train_data để nhặt ra mỗi class một ảnh
for i in range(len(train_data)):
    image, mask, label = train_data[i]
    
    # Xử lý nếu label là Tensor
    if isinstance(label, torch.Tensor):
        label = label.item()
    
    # Nếu class này chưa có trong danh sách tìm thấy thì thêm vào
    if label not in found_samples:
        found_samples[label] = (image, mask)
    
    # Nếu đã tìm đủ 4 class thì dừng vòng lặp cho nhanh
    if len(found_samples) == num_classes_to_find:
        break

# Sắp xếp label (0, 1, 2, 3) để hiển thị theo thứ tự
sorted_labels = sorted(found_samples.keys())
num_cols = len(sorted_labels)

# 2. Vẽ hình
if num_cols == 0:
    print("Không tìm thấy dữ liệu nào!")
else:
    # Tạo lưới plot: 2 hàng, số cột = số class tìm được
    fig, ax = plt.subplots(2, num_cols, figsize=(4 * num_cols, 6))

    for i, label in enumerate(sorted_labels):
        image, mask = found_samples[label]

        # --- Hàng 1: Ảnh gốc ---
        # Xử lý để hiển thị đúng định dạng (H, W, C)
        if isinstance(image, torch.Tensor):
            img_show = image.permute(1, 2, 0).cpu().numpy()
            
            # (Tuỳ chọn) Nếu bạn đã Normalize ảnh (trừ mean, chia std), 
            # ảnh hiển thị có thể bị tối hoặc màu lạ. 
            # Dòng dưới đây giúp đưa giá trị về khoảng [0, 1] để dễ nhìn hơn:
            img_show = (img_show - img_show.min()) / (img_show.max() - img_show.min())
        else:
            img_show = image

        # Nếu chỉ có 1 cột (1 class), ax là mảng 1 chiều, nếu nhiều cột là 2 chiều
        if num_cols > 1:
            ax_img = ax[0, i]
            ax_mask = ax[1, i]
        else:
            ax_img = ax[0]
            ax_mask = ax[1]

        ax_img.imshow(img_show)
        ax_img.set_title(f"Class: {label}")
        ax_img.axis('off')

        # --- Hàng 2: Mask ---
        if isinstance(mask, torch.Tensor):
            mask_show = mask.squeeze(0).cpu().numpy()
        else:
            mask_show = mask

        ax_mask.imshow(mask_show, cmap='gray')
        ax_mask.set_title(f"Mask - Class {label}")
        ax_mask.axis('off')

    plt.tight_layout()
    plt.show()

# %%
train_size = int(0.8 * len(train_data))
valid_test_size = len(train_data) - train_size

# Chia dữ liệu thành train (80%) và tạm thời là validation/test (20%)
train_dataset, valid_test_dataset = random_split(train_data, [train_size, valid_test_size])

# Tiếp tục chia valid_test_dataset thành validation (10%) và test (10%)
valid_size = int(0.5 * valid_test_size)
test_size = valid_test_size - valid_size
valid_dataset, test_dataset = random_split(valid_test_dataset, [valid_size, test_size])

# You can check the sizes to verify
print(f"Training set: {len(train_dataset)} samples")
print(f"Validation set: {len(valid_dataset)} samples")
print(f"Test set: {len(test_dataset)} samples")
# Out:
# Training set: 4000 samples
# Validation set: 500 samples
# Test set: 500 samples

# %%
train_loader = DataLoader(train_dataset, shuffle=True, batch_size=32)
valid_loader = DataLoader(valid_dataset, shuffle=False, batch_size=32)
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=32)

# %% [markdown]
# # 3. Load model

# %%
class decode(torch.nn.Module):
    def __init__(self, in_channel, middle_channel, out_channel):
        super(decode, self).__init__()
        self.transpose = torch.nn.ConvTranspose2d(in_channel, in_channel, kernel_size=2, stride=2)
        self.conv1 = nn.Conv2d(in_channel + middle_channel, out_channel, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(out_channel)
        self.relu1 = nn.ReLU(inplace=True)

        self.conv2 = nn.Conv2d(out_channel, out_channel, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(out_channel)
        self.relu2 = nn.ReLU(inplace=True)


    def forward(self, x1, x2):
        x1 = self.transpose(x1)
        if x1.size() != x2.size():
            x1 = nn.functional.interpolate(x1, size=x2.shape[2:], 
                                            mode='bilinear', align_corners=False)
            
        x = torch.cat([x1, x2], dim=1)
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu1(x)
        
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu2(x)      
        return x

# %%
class MultiTaskModel(nn.Module):
    def __init__(self, n_classes, n_segment, in_channels, input_size=(256,256)):
        super(MultiTaskModel, self).__init__()

        # load pretrained EfficientNet-B4
        efficient = models.efficientnet_b4(weights=models.EfficientNet_B4_Weights.DEFAULT)
        features = efficient.features
        
        # encoder
        self.encoder1 = nn.Sequential(
            features[0],
            features[1]
        )
        self.encoder2 = nn.Sequential(
            features[2]
        )
        self.encoder3 = nn.Sequential(
            features[3],
            features[4]
        )
        self.encoder4 = nn.Sequential(
            features[5],
            features[6]
        )
        self.encoder5 = nn.Sequential(
            features[7],
            features[8]
        )

        self.brigde = nn.Sequential(
            nn.BatchNorm2d(1792, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True),
            nn.AdaptiveAvgPool2d(output_size=1),
            nn.Dropout(0.1),
            nn.SiLU(),
        )

        # decoder

        self.decode1 = decode(1792, 272, 256) # In: 1792, Skip: 160
        self.decode2 = decode(256, 112, 128)   # In: 256, Skip: 56
        self.decode3 = decode(128, 32, 64)    # In: 128, Skip: 32
        self.decode4 = decode(64, 24, 32)     # In: 64, Skip: 24
        
        # output segment
        self.segmentation_head = nn.Sequential(
            nn.ConvTranspose2d(32, 16, kernel_size=2, stride=2),
            nn.ReLU(inplace=True),
            nn.Conv2d(16, n_segment, kernel_size=1)  # Output layer
        )

        # output classify
        self.classify = nn.Sequential(
            nn.AdaptiveAvgPool2d(output_size=1),
            nn.Flatten(),
            nn.Dropout(p=0.4),
            nn.Linear(in_features=1792,
                      out_features=n_classes,
                      bias=True)
        )

    def forward(self, inputs):
        x1 = self.encoder1(inputs)
        x2 = self.encoder2(x1)
        x3 = self.encoder3(x2)
        x4 = self.encoder4(x3)
        x5 = self.encoder5(x4)
        
        x_brigde = self.brigde(x5)

        x6 = self.decode1(x_brigde, x4)
        x7 = self.decode2(x6, x3)
        x8 = self.decode3(x7, x2)
        x9 = self.decode4(x8, x1)

        

        out_classify = self.classify(x5)

        
        out_segment = self.segmentation_head(x9)
        
        return out_classify, out_segment

# %%
model = MultiTaskModel(n_classes= 4, n_segment=1, in_channels=3, input_size=(256, 256))
model = model.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b4_rwightman-23ab8bcd.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b4_rwightman-23ab8bcd.pth
# 100%|██████████| 74.5M/74.5M [00:00<00:00, 178MB/s]

# %% [markdown]
# # 4. Code loss

# %%
class DiceLoss(nn.Module):
    def __init__(self, smooth=1e-6):
        super(DiceLoss, self).__init__()
        self.smooth = smooth

    def forward(self, predictions, targets):
        # 1. Chuyển logits thành xác suất
        predictions = torch.sigmoid(predictions)

        # 2. Flatten: (Batch_Size, Channel, H, W) -> (Batch_Size, -1)
        # Giữ lại chiều Batch_Size để tính riêng từng ảnh
        predictions = predictions.view(predictions.size(0), -1)
        targets = targets.view(targets.size(0), -1)

        # 3. Tính Intersection và Union cho TỪNG ảnh (dim=1)
        intersection = (predictions * targets).sum(dim=1)
        union = predictions.sum(dim=1) + targets.sum(dim=1)

        # 4. Tính Dice cho từng ảnh
        dice = (2. * intersection + self.smooth) / (union + self.smooth)

        # 5. Trả về 1 - dice trung bình của cả batch
        return 1 - dice.mean()

class CombinedLoss(nn.Module):
    def __init__(self, weight_dice=0.5, weight_bce=0.5):
        super(CombinedLoss, self).__init__()
        self.dice = DiceLoss()
        # BCEWithLogitsLoss đã tích hợp Sigmoid bên trong, rất ổn định
        self.bce = nn.BCEWithLogitsLoss() 
        self.weight_dice = weight_dice
        self.weight_bce = weight_bce

    def forward(self, predictions, targets):
        # predictions: Logits (chưa qua sigmoid)
        # targets: Binary mask (0 hoặc 1)
        
        dice_loss = self.dice(predictions, targets)
        bce_loss = self.bce(predictions, targets)
        
        return self.weight_dice * dice_loss + self.weight_bce * bce_loss

# Metrics
def calculate_iou(predictions, targets, threshold=0.5):
    predictions = torch.sigmoid(predictions)
    predictions = (predictions > threshold).float()
    
    intersection = (predictions * targets).sum(dim=(1, 2, 3))
    union = predictions.sum(dim=(1, 2, 3)) + targets.sum(dim=(1, 2, 3)) - intersection
    
    iou = (intersection + 1e-6) / (union + 1e-6)
    return iou.mean()

def calculate_dice(predictions, targets, threshold=0.5):
    predictions = torch.sigmoid(predictions)
    predictions = (predictions > threshold).float()
    
    intersection = (predictions * targets).sum(dim=(1, 2, 3))
    dice = (2. * intersection + 1e-6) / (predictions.sum(dim=(1, 2, 3)) + targets.sum(dim=(1, 2, 3)) + 1e-6)
    return dice.mean()

# %%
class SimpleMultiTaskLoss(nn.Module):
    """
    Hàm loss đơn giản với trọng số cố định (Fixed Weight).
    """
    def __init__(self, weight_seg=0.5, weight_cls=0.5):
        super(SimpleMultiTaskLoss, self).__init__()
        # Loss cho Segmentation (đã có từ cell 14)
        self.loss_seg = CombinedLoss() 
        # Loss cho Classification
        self.loss_classify = nn.CrossEntropyLoss()
        
        self.weight_seg = weight_seg
        self.weight_cls = weight_cls
        
    def forward(self, seg_logits, seg_labels, classify_logits, classify_labels):
        # Tính loss riêng lẻ
        loss_seg = self.loss_seg(seg_logits, seg_labels)
        loss_classify = self.loss_classify(classify_logits, classify_labels)
        
        # Cộng loss theo trọng số cố định
        total_loss = (self.weight_seg * loss_seg) + (self.weight_cls * loss_classify)
        
        return total_loss

# %% [markdown]
# # 5. Train model

# %%
def train(model, criterion, optimizer, train_loader, device):
    model.train()
    total_loss = 0
    corrects = 0
    total_iou = 0
    total_dice = 0
    for i, (images, masks, targets) in enumerate(train_loader):
        optimizer.zero_grad()

        images = images.to(device)
        masks = masks.to(device)
        targets = targets.to(device)
        
        output_class, output_seg = model(images)
        
        loss = criterion(output_seg, masks, output_class, targets)

        _, pred = torch.max(output_class, 1)
        corrects += torch.sum(targets == pred).item()

        loss.backward()
        optimizer.step()

        with torch.no_grad():
            iou = calculate_iou(output_seg, masks)
            dice = calculate_dice(output_seg, masks)
        
        total_loss += loss.item()
        total_iou += iou.item()
        total_dice += dice.item()
    return total_loss / len(train_loader), total_iou/len(train_loader), total_dice/len(train_loader), corrects/len(train_loader.dataset)

def valid(model, criterion, valid_loader, device):
    model.eval()
    with torch.no_grad():
        total_loss = 0
        corrects = 0
        total_iou = 0
        total_dice = 0
        for i, (images, masks, targets) in enumerate(valid_loader):
            images = images.to(device)
            masks = masks.to(device)
            targets = targets.to(device)
    
            output_class, output_seg = model(images)
            loss =criterion(output_seg, masks, output_class, targets)
    
            _, pred = torch.max(output_class, 1)
            corrects += torch.sum(targets == pred).item()
            
            iou = calculate_iou(output_seg, masks)
            dice = calculate_dice(output_seg, masks)
            
            total_loss += loss.item()
            total_iou += iou.item()
            total_dice += dice.item()
    return total_loss / len(valid_loader), total_iou/len(valid_loader), total_dice/len(valid_loader), corrects/len(valid_loader.dataset)

# %%
results = {
    "train_loss" : [],
    "iou_train"  : [],
    "dice_train" : [],
    "acc_train"  : [],
    "valid_loss" : [],
    "iou_valid"  : [],
    "dice_valid" : [],
    "acc_valid"  : []
    }
# configure
criterion = SimpleMultiTaskLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)
epochs = 100
for epoch in range(epochs):
    train_loss, iou_train, dice_train, acc_train = train(model, criterion, optimizer, train_loader, device)
    valid_loss, iou_valid, dice_valid, acc_valid = valid(model, criterion, valid_loader, device)
    
    print(f'Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, IoU Score : {iou_train:.4f}, Dice Score : {dice_train:.4f}, Acc : {acc_train:.4f}')
    print(f'Epoch {epoch+1}/{epochs}, Valid Loss: {valid_loss:.4f}, IoU Score : {iou_valid:.4f}, Dice Score : {dice_valid:.4f}, Acc : {acc_valid:.4f}')
    print('-------------------------------------------------------------------------------------------------------------------------------')

    results["train_loss"].append(train_loss)
    results["iou_train"].append(iou_train)
    results["dice_train"].append(dice_train)
    results["acc_train"].append(acc_train)
    results["valid_loss"].append(valid_loss)
    results["iou_valid"].append(iou_valid)
    results["dice_valid"].append(dice_valid)
    results["acc_valid"].append(acc_valid)
# Out:
# Epoch 1/100, Train Loss: 0.8950, IoU Score : 0.0162, Dice Score : 0.0313, Acc : 0.6877
# Epoch 1/100, Valid Loss: 0.6043, IoU Score : 0.0255, Dice Score : 0.0484, Acc : 0.8460
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 2/100, Train Loss: 0.5258, IoU Score : 0.1029, Dice Score : 0.1691, Acc : 0.8995
# Epoch 2/100, Valid Loss: 0.4648, IoU Score : 0.1817, Dice Score : 0.2775, Acc : 0.9320
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 3/100, Train Loss: 0.4333, IoU Score : 0.2999, Dice Score : 0.4088, Acc : 0.9425
# Epoch 3/100, Valid Loss: 0.4059, IoU Score : 0.3777, Dice Score : 0.4788, Acc : 0.9520
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 4/100, Train Loss: 0.3614, IoU Score : 0.5688, Dice Score : 0.6736, Acc : 0.9730
# Epoch 4/100, Valid Loss: 0.3673, IoU Score : 0.6543, Dice Score : 0.7484, Acc : 0.9520
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 5/100, Train Loss: 0.3131, IoU Score : 0.6633, Dice Score : 0.7604, Acc : 0.9845
# Epoch 5/100, Valid Loss: 0.3221, IoU Score : 0.6883, Dice Score : 0.7775, Acc : 0.9680
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 6/100, Train Loss: 0.2834, IoU Score : 0.6984, Dice Score : 0.7903, Acc : 0.9862
# Epoch 6/100, Valid Loss: 0.2929, IoU Score : 0.6930, Dice Score : 0.7829, Acc : 0.9720
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 7/100, Train Loss: 0.2578, IoU Score : 0.7174, Dice Score : 0.8034, Acc : 0.9875
# Epoch 7/100, Valid Loss: 0.2657, IoU Score : 0.6708, Dice Score : 0.7520, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 8/100, Train Loss: 0.2245, IoU Score : 0.7344, Dice Score : 0.8143, Acc : 0.9942
# Epoch 8/100, Valid Loss: 0.2250, IoU Score : 0.7226, Dice Score : 0.8012, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 9/100, Train Loss: 0.1981, IoU Score : 0.7547, Dice Score : 0.8297, Acc : 0.9938
# Epoch 9/100, Valid Loss: 0.2250, IoU Score : 0.7291, Dice Score : 0.8005, Acc : 0.9780
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 10/100, Train Loss: 0.1767, IoU Score : 0.7580, Dice Score : 0.8300, Acc : 0.9955
# Epoch 10/100, Valid Loss: 0.2002, IoU Score : 0.7270, Dice Score : 0.7976, Acc : 0.9800
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 11/100, Train Loss: 0.1608, IoU Score : 0.7836, Dice Score : 0.8521, Acc : 0.9968
# Epoch 11/100, Valid Loss: 0.1845, IoU Score : 0.7784, Dice Score : 0.8480, Acc : 0.9800
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 12/100, Train Loss: 0.1545, IoU Score : 0.7908, Dice Score : 0.8570, Acc : 0.9948
# Epoch 12/100, Valid Loss: 0.1803, IoU Score : 0.7615, Dice Score : 0.8279, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 13/100, Train Loss: 0.1448, IoU Score : 0.8030, Dice Score : 0.8671, Acc : 0.9978
# Epoch 13/100, Valid Loss: 0.1745, IoU Score : 0.7595, Dice Score : 0.8281, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 14/100, Train Loss: 0.1399, IoU Score : 0.8127, Dice Score : 0.8745, Acc : 0.9970
# Epoch 14/100, Valid Loss: 0.1666, IoU Score : 0.7560, Dice Score : 0.8228, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 15/100, Train Loss: 0.1333, IoU Score : 0.8166, Dice Score : 0.8775, Acc : 0.9982
# Epoch 15/100, Valid Loss: 0.1662, IoU Score : 0.7806, Dice Score : 0.8456, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 16/100, Train Loss: 0.1309, IoU Score : 0.8097, Dice Score : 0.8699, Acc : 0.9975
# Epoch 16/100, Valid Loss: 0.1727, IoU Score : 0.7771, Dice Score : 0.8421, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 17/100, Train Loss: 0.1264, IoU Score : 0.8210, Dice Score : 0.8798, Acc : 0.9990
# Epoch 17/100, Valid Loss: 0.1660, IoU Score : 0.7717, Dice Score : 0.8374, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 18/100, Train Loss: 0.1225, IoU Score : 0.8423, Dice Score : 0.8990, Acc : 0.9990
# Epoch 18/100, Valid Loss: 0.1656, IoU Score : 0.7750, Dice Score : 0.8416, Acc : 0.9800
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 19/100, Train Loss: 0.1207, IoU Score : 0.8379, Dice Score : 0.8942, Acc : 0.9982
# Epoch 19/100, Valid Loss: 0.1690, IoU Score : 0.7654, Dice Score : 0.8324, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 20/100, Train Loss: 0.1173, IoU Score : 0.8429, Dice Score : 0.8981, Acc : 0.9988
# Epoch 20/100, Valid Loss: 0.1859, IoU Score : 0.7771, Dice Score : 0.8418, Acc : 0.9700
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 21/100, Train Loss: 0.1173, IoU Score : 0.8406, Dice Score : 0.8945, Acc : 0.9972
# Epoch 21/100, Valid Loss: 0.1689, IoU Score : 0.7810, Dice Score : 0.8449, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 22/100, Train Loss: 0.1144, IoU Score : 0.8486, Dice Score : 0.9020, Acc : 0.9980
# Epoch 22/100, Valid Loss: 0.1638, IoU Score : 0.7776, Dice Score : 0.8412, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 23/100, Train Loss: 0.1127, IoU Score : 0.8486, Dice Score : 0.9015, Acc : 0.9978
# Epoch 23/100, Valid Loss: 0.1490, IoU Score : 0.7922, Dice Score : 0.8554, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 24/100, Train Loss: 0.1090, IoU Score : 0.8510, Dice Score : 0.9032, Acc : 0.9992
# Epoch 24/100, Valid Loss: 0.1545, IoU Score : 0.7740, Dice Score : 0.8394, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 25/100, Train Loss: 0.1083, IoU Score : 0.8540, Dice Score : 0.9058, Acc : 0.9988
# Epoch 25/100, Valid Loss: 0.1567, IoU Score : 0.7575, Dice Score : 0.8230, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 26/100, Train Loss: 0.1069, IoU Score : 0.8603, Dice Score : 0.9111, Acc : 0.9975
# Epoch 26/100, Valid Loss: 0.1639, IoU Score : 0.7839, Dice Score : 0.8473, Acc : 0.9800
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 27/100, Train Loss: 0.1034, IoU Score : 0.8508, Dice Score : 0.9008, Acc : 0.9990
# Epoch 27/100, Valid Loss: 0.1619, IoU Score : 0.7583, Dice Score : 0.8208, Acc : 0.9780
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 28/100, Train Loss: 0.1020, IoU Score : 0.8500, Dice Score : 0.8994, Acc : 0.9982
# Epoch 28/100, Valid Loss: 0.1582, IoU Score : 0.7705, Dice Score : 0.8339, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 29/100, Train Loss: 0.0994, IoU Score : 0.8558, Dice Score : 0.9035, Acc : 0.9995
# Epoch 29/100, Valid Loss: 0.1607, IoU Score : 0.7853, Dice Score : 0.8473, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 30/100, Train Loss: 0.0977, IoU Score : 0.8751, Dice Score : 0.9215, Acc : 0.9985
# Epoch 30/100, Valid Loss: 0.1499, IoU Score : 0.7830, Dice Score : 0.8444, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 31/100, Train Loss: 0.0958, IoU Score : 0.8679, Dice Score : 0.9132, Acc : 0.9988
# Epoch 31/100, Valid Loss: 0.1435, IoU Score : 0.7523, Dice Score : 0.8142, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 32/100, Train Loss: 0.0937, IoU Score : 0.8641, Dice Score : 0.9085, Acc : 0.9992
# Epoch 32/100, Valid Loss: 0.1606, IoU Score : 0.7822, Dice Score : 0.8433, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 33/100, Train Loss: 0.0917, IoU Score : 0.8796, Dice Score : 0.9230, Acc : 0.9995
# Epoch 33/100, Valid Loss: 0.1575, IoU Score : 0.7821, Dice Score : 0.8427, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 34/100, Train Loss: 0.0901, IoU Score : 0.8646, Dice Score : 0.9071, Acc : 0.9992
# Epoch 34/100, Valid Loss: 0.1534, IoU Score : 0.7414, Dice Score : 0.8015, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 35/100, Train Loss: 0.0891, IoU Score : 0.8646, Dice Score : 0.9070, Acc : 0.9992
# Epoch 35/100, Valid Loss: 0.1405, IoU Score : 0.7600, Dice Score : 0.8219, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 36/100, Train Loss: 0.0882, IoU Score : 0.8762, Dice Score : 0.9179, Acc : 0.9988
# Epoch 36/100, Valid Loss: 0.1423, IoU Score : 0.7935, Dice Score : 0.8544, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 37/100, Train Loss: 0.0863, IoU Score : 0.8775, Dice Score : 0.9182, Acc : 0.9992
# Epoch 37/100, Valid Loss: 0.1559, IoU Score : 0.7749, Dice Score : 0.8343, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 38/100, Train Loss: 0.0840, IoU Score : 0.8827, Dice Score : 0.9226, Acc : 0.9998
# Epoch 38/100, Valid Loss: 0.1628, IoU Score : 0.7703, Dice Score : 0.8292, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 39/100, Train Loss: 0.0841, IoU Score : 0.8832, Dice Score : 0.9230, Acc : 0.9988
# Epoch 39/100, Valid Loss: 0.1676, IoU Score : 0.7971, Dice Score : 0.8571, Acc : 0.9800
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 40/100, Train Loss: 0.0830, IoU Score : 0.8860, Dice Score : 0.9252, Acc : 0.9988
# Epoch 40/100, Valid Loss: 0.1558, IoU Score : 0.7828, Dice Score : 0.8426, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 41/100, Train Loss: 0.0822, IoU Score : 0.8821, Dice Score : 0.9205, Acc : 0.9988
# Epoch 41/100, Valid Loss: 0.1526, IoU Score : 0.7595, Dice Score : 0.8187, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 42/100, Train Loss: 0.0800, IoU Score : 0.8798, Dice Score : 0.9176, Acc : 0.9998
# Epoch 42/100, Valid Loss: 0.1376, IoU Score : 0.7816, Dice Score : 0.8400, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 43/100, Train Loss: 0.0801, IoU Score : 0.8754, Dice Score : 0.9137, Acc : 0.9990
# Epoch 43/100, Valid Loss: 0.1563, IoU Score : 0.7604, Dice Score : 0.8204, Acc : 0.9800
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 44/100, Train Loss: 0.0783, IoU Score : 0.8895, Dice Score : 0.9271, Acc : 0.9995
# Epoch 44/100, Valid Loss: 0.1497, IoU Score : 0.7936, Dice Score : 0.8526, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 45/100, Train Loss: 0.0780, IoU Score : 0.8787, Dice Score : 0.9158, Acc : 0.9998
# Epoch 45/100, Valid Loss: 0.1327, IoU Score : 0.7742, Dice Score : 0.8333, Acc : 0.9920
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 46/100, Train Loss: 0.0783, IoU Score : 0.8858, Dice Score : 0.9228, Acc : 0.9980
# Epoch 46/100, Valid Loss: 0.1263, IoU Score : 0.7925, Dice Score : 0.8514, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 47/100, Train Loss: 0.0767, IoU Score : 0.8817, Dice Score : 0.9186, Acc : 0.9985
# Epoch 47/100, Valid Loss: 0.1339, IoU Score : 0.7716, Dice Score : 0.8306, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 48/100, Train Loss: 0.0762, IoU Score : 0.8800, Dice Score : 0.9167, Acc : 0.9990
# Epoch 48/100, Valid Loss: 0.1311, IoU Score : 0.7631, Dice Score : 0.8220, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 49/100, Train Loss: 0.0745, IoU Score : 0.8789, Dice Score : 0.9157, Acc : 0.9995
# Epoch 49/100, Valid Loss: 0.1296, IoU Score : 0.7861, Dice Score : 0.8458, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 50/100, Train Loss: 0.0737, IoU Score : 0.8951, Dice Score : 0.9307, Acc : 0.9990
# Epoch 50/100, Valid Loss: 0.1375, IoU Score : 0.7909, Dice Score : 0.8501, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 51/100, Train Loss: 0.0721, IoU Score : 0.8878, Dice Score : 0.9227, Acc : 0.9998
# Epoch 51/100, Valid Loss: 0.1436, IoU Score : 0.7808, Dice Score : 0.8409, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 52/100, Train Loss: 0.0729, IoU Score : 0.8965, Dice Score : 0.9306, Acc : 0.9992
# Epoch 52/100, Valid Loss: 0.1367, IoU Score : 0.7720, Dice Score : 0.8317, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 53/100, Train Loss: 0.0715, IoU Score : 0.8875, Dice Score : 0.9217, Acc : 0.9995
# Epoch 53/100, Valid Loss: 0.1365, IoU Score : 0.7652, Dice Score : 0.8242, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 54/100, Train Loss: 0.0709, IoU Score : 0.8898, Dice Score : 0.9237, Acc : 0.9992
# Epoch 54/100, Valid Loss: 0.1414, IoU Score : 0.7877, Dice Score : 0.8456, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 55/100, Train Loss: 0.0702, IoU Score : 0.8996, Dice Score : 0.9336, Acc : 0.9995
# Epoch 55/100, Valid Loss: 0.1350, IoU Score : 0.7857, Dice Score : 0.8451, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 56/100, Train Loss: 0.0698, IoU Score : 0.8887, Dice Score : 0.9222, Acc : 0.9998
# Epoch 56/100, Valid Loss: 0.1317, IoU Score : 0.7748, Dice Score : 0.8340, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 57/100, Train Loss: 0.0692, IoU Score : 0.8933, Dice Score : 0.9267, Acc : 0.9998
# Epoch 57/100, Valid Loss: 0.1490, IoU Score : 0.7256, Dice Score : 0.7847, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 58/100, Train Loss: 0.0683, IoU Score : 0.8896, Dice Score : 0.9222, Acc : 0.9995
# Epoch 58/100, Valid Loss: 0.1527, IoU Score : 0.7552, Dice Score : 0.8156, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 59/100, Train Loss: 0.0691, IoU Score : 0.8909, Dice Score : 0.9232, Acc : 0.9988
# Epoch 59/100, Valid Loss: 0.1348, IoU Score : 0.7656, Dice Score : 0.8263, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 60/100, Train Loss: 0.0680, IoU Score : 0.8917, Dice Score : 0.9242, Acc : 0.9995
# Epoch 60/100, Valid Loss: 0.1388, IoU Score : 0.7165, Dice Score : 0.7759, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 61/100, Train Loss: 0.0678, IoU Score : 0.8831, Dice Score : 0.9157, Acc : 0.9992
# Epoch 61/100, Valid Loss: 0.1377, IoU Score : 0.7989, Dice Score : 0.8578, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 62/100, Train Loss: 0.0670, IoU Score : 0.8977, Dice Score : 0.9299, Acc : 0.9995
# Epoch 62/100, Valid Loss: 0.1404, IoU Score : 0.7770, Dice Score : 0.8376, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 63/100, Train Loss: 0.0660, IoU Score : 0.9027, Dice Score : 0.9343, Acc : 1.0000
# Epoch 63/100, Valid Loss: 0.1382, IoU Score : 0.7714, Dice Score : 0.8318, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 64/100, Train Loss: 0.0662, IoU Score : 0.9017, Dice Score : 0.9333, Acc : 0.9998
# Epoch 64/100, Valid Loss: 0.1372, IoU Score : 0.7657, Dice Score : 0.8248, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 65/100, Train Loss: 0.0653, IoU Score : 0.8908, Dice Score : 0.9227, Acc : 1.0000
# Epoch 65/100, Valid Loss: 0.1346, IoU Score : 0.7421, Dice Score : 0.8033, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 66/100, Train Loss: 0.0649, IoU Score : 0.8890, Dice Score : 0.9205, Acc : 0.9992
# Epoch 66/100, Valid Loss: 0.1380, IoU Score : 0.7472, Dice Score : 0.8056, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 67/100, Train Loss: 0.0641, IoU Score : 0.8968, Dice Score : 0.9282, Acc : 0.9990
# Epoch 67/100, Valid Loss: 0.1500, IoU Score : 0.7657, Dice Score : 0.8252, Acc : 0.9780
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 68/100, Train Loss: 0.0645, IoU Score : 0.8923, Dice Score : 0.9240, Acc : 0.9990
# Epoch 68/100, Valid Loss: 0.1388, IoU Score : 0.7694, Dice Score : 0.8278, Acc : 0.9800
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 69/100, Train Loss: 0.0636, IoU Score : 0.8998, Dice Score : 0.9312, Acc : 0.9995
# Epoch 69/100, Valid Loss: 0.1407, IoU Score : 0.7736, Dice Score : 0.8318, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 70/100, Train Loss: 0.0630, IoU Score : 0.9007, Dice Score : 0.9320, Acc : 0.9995
# Epoch 70/100, Valid Loss: 0.1395, IoU Score : 0.7736, Dice Score : 0.8328, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 71/100, Train Loss: 0.0627, IoU Score : 0.9024, Dice Score : 0.9325, Acc : 0.9995
# Epoch 71/100, Valid Loss: 0.1368, IoU Score : 0.7704, Dice Score : 0.8290, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 72/100, Train Loss: 0.0630, IoU Score : 0.9015, Dice Score : 0.9322, Acc : 0.9992
# Epoch 72/100, Valid Loss: 0.1222, IoU Score : 0.7635, Dice Score : 0.8227, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 73/100, Train Loss: 0.0626, IoU Score : 0.9040, Dice Score : 0.9342, Acc : 0.9995
# Epoch 73/100, Valid Loss: 0.1200, IoU Score : 0.7778, Dice Score : 0.8358, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 74/100, Train Loss: 0.0618, IoU Score : 0.8987, Dice Score : 0.9282, Acc : 1.0000
# Epoch 74/100, Valid Loss: 0.1254, IoU Score : 0.7916, Dice Score : 0.8501, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 75/100, Train Loss: 0.0616, IoU Score : 0.9049, Dice Score : 0.9338, Acc : 1.0000
# Epoch 75/100, Valid Loss: 0.1278, IoU Score : 0.7797, Dice Score : 0.8383, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 76/100, Train Loss: 0.0621, IoU Score : 0.9060, Dice Score : 0.9350, Acc : 0.9995
# Epoch 76/100, Valid Loss: 0.1300, IoU Score : 0.7755, Dice Score : 0.8340, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 77/100, Train Loss: 0.0619, IoU Score : 0.9027, Dice Score : 0.9315, Acc : 0.9998
# Epoch 77/100, Valid Loss: 0.1393, IoU Score : 0.7166, Dice Score : 0.7759, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 78/100, Train Loss: 0.0620, IoU Score : 0.8944, Dice Score : 0.9239, Acc : 1.0000
# Epoch 78/100, Valid Loss: 0.1368, IoU Score : 0.7118, Dice Score : 0.7716, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 79/100, Train Loss: 0.0622, IoU Score : 0.9014, Dice Score : 0.9319, Acc : 1.0000
# Epoch 79/100, Valid Loss: 0.1384, IoU Score : 0.7832, Dice Score : 0.8410, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 80/100, Train Loss: 0.0620, IoU Score : 0.9180, Dice Score : 0.9470, Acc : 0.9995
# Epoch 80/100, Valid Loss: 0.1469, IoU Score : 0.7441, Dice Score : 0.8020, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 81/100, Train Loss: 0.0615, IoU Score : 0.9164, Dice Score : 0.9450, Acc : 1.0000
# Epoch 81/100, Valid Loss: 0.1332, IoU Score : 0.7973, Dice Score : 0.8561, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 82/100, Train Loss: 0.0615, IoU Score : 0.9142, Dice Score : 0.9424, Acc : 1.0000
# Epoch 82/100, Valid Loss: 0.1423, IoU Score : 0.7606, Dice Score : 0.8193, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 83/100, Train Loss: 0.0618, IoU Score : 0.9158, Dice Score : 0.9439, Acc : 0.9992
# Epoch 83/100, Valid Loss: 0.1550, IoU Score : 0.7590, Dice Score : 0.8184, Acc : 0.9800
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 84/100, Train Loss: 0.0627, IoU Score : 0.9073, Dice Score : 0.9357, Acc : 0.9995
# Epoch 84/100, Valid Loss: 0.1418, IoU Score : 0.7742, Dice Score : 0.8334, Acc : 0.9800
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 85/100, Train Loss: 0.0618, IoU Score : 0.9090, Dice Score : 0.9372, Acc : 0.9992
# Epoch 85/100, Valid Loss: 0.1308, IoU Score : 0.7754, Dice Score : 0.8343, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 86/100, Train Loss: 0.0614, IoU Score : 0.9050, Dice Score : 0.9324, Acc : 0.9998
# Epoch 86/100, Valid Loss: 0.1302, IoU Score : 0.7894, Dice Score : 0.8476, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 87/100, Train Loss: 0.0612, IoU Score : 0.9118, Dice Score : 0.9392, Acc : 1.0000
# Epoch 87/100, Valid Loss: 0.1338, IoU Score : 0.7774, Dice Score : 0.8373, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 88/100, Train Loss: 0.0609, IoU Score : 0.9126, Dice Score : 0.9396, Acc : 1.0000
# Epoch 88/100, Valid Loss: 0.1396, IoU Score : 0.7836, Dice Score : 0.8411, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 89/100, Train Loss: 0.0616, IoU Score : 0.9109, Dice Score : 0.9379, Acc : 0.9990
# Epoch 89/100, Valid Loss: 0.1423, IoU Score : 0.7583, Dice Score : 0.8157, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 90/100, Train Loss: 0.0619, IoU Score : 0.9123, Dice Score : 0.9399, Acc : 0.9990
# Epoch 90/100, Valid Loss: 0.1415, IoU Score : 0.7919, Dice Score : 0.8508, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 91/100, Train Loss: 0.0611, IoU Score : 0.9192, Dice Score : 0.9463, Acc : 0.9998
# Epoch 91/100, Valid Loss: 0.1377, IoU Score : 0.7788, Dice Score : 0.8373, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 92/100, Train Loss: 0.0620, IoU Score : 0.8978, Dice Score : 0.9268, Acc : 0.9995
# Epoch 92/100, Valid Loss: 0.1527, IoU Score : 0.7653, Dice Score : 0.8242, Acc : 0.9840
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 93/100, Train Loss: 0.0610, IoU Score : 0.9158, Dice Score : 0.9429, Acc : 1.0000
# Epoch 93/100, Valid Loss: 0.1392, IoU Score : 0.7933, Dice Score : 0.8516, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 94/100, Train Loss: 0.0611, IoU Score : 0.9192, Dice Score : 0.9458, Acc : 0.9995
# Epoch 94/100, Valid Loss: 0.1576, IoU Score : 0.8053, Dice Score : 0.8631, Acc : 0.9820
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 95/100, Train Loss: 0.0611, IoU Score : 0.9191, Dice Score : 0.9465, Acc : 1.0000
# Epoch 95/100, Valid Loss: 0.1414, IoU Score : 0.7558, Dice Score : 0.8153, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 96/100, Train Loss: 0.0607, IoU Score : 0.9195, Dice Score : 0.9462, Acc : 1.0000
# Epoch 96/100, Valid Loss: 0.1382, IoU Score : 0.7795, Dice Score : 0.8382, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 97/100, Train Loss: 0.0606, IoU Score : 0.9184, Dice Score : 0.9446, Acc : 1.0000
# Epoch 97/100, Valid Loss: 0.1404, IoU Score : 0.7406, Dice Score : 0.7996, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 98/100, Train Loss: 0.0620, IoU Score : 0.9192, Dice Score : 0.9454, Acc : 0.9992
# Epoch 98/100, Valid Loss: 0.1290, IoU Score : 0.7841, Dice Score : 0.8426, Acc : 0.9900
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 99/100, Train Loss: 0.0616, IoU Score : 0.9208, Dice Score : 0.9470, Acc : 0.9992
# Epoch 99/100, Valid Loss: 0.1415, IoU Score : 0.7622, Dice Score : 0.8203, Acc : 0.9860
# -------------------------------------------------------------------------------------------------------------------------------
# Epoch 100/100, Train Loss: 0.0609, IoU Score : 0.9123, Dice Score : 0.9385, Acc : 0.9998
# Epoch 100/100, Valid Loss: 0.1335, IoU Score : 0.7793, Dice Score : 0.8377, Acc : 0.9880
# -------------------------------------------------------------------------------------------------------------------------------

# %%
model.eval()
masks = []

with torch.no_grad():
    fig, ax = plt.subplots(2, 3, figsize=(10, 6))
    for i in range(3):
        image = test_dataset[i][0].to(device).unsqueeze(0)
        mask = test_dataset[i][1].to(device)
        target = test_dataset[i][2]

        output_class, output_seg = model(image)
        _, pred = torch.max(output_class, 1)
        
        output_seg=torch.sigmoid(output_seg).cpu().squeeze().numpy()
        output_seg = (output_seg > 0.5).astype(np.uint8)

           # Hàng 1: ảnh pred
        ax[0, i].imshow(output_seg, cmap='gray')
        ax[0, i].set_title(f"Class: {pred.cpu().numpy()[0]}")
        ax[0, i].axis('off')
    
        # Hàng 2: mask
        ax[1, i].imshow(mask.cpu().squeeze().numpy(), cmap='gray') 
        ax[1, i].set_title(f"Class: {target}")
        ax[1, i].axis('off')
    
    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.title("Loss Score")
plt.plot(results["train_loss"], label="Train loss")
plt.plot(results["valid_loss"], label="Valid loss")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
plt.figure(figsize=(10, 5))
plt.title("IoU Score")
plt.plot(results["iou_train"], label="Train IoU")
plt.plot(results["iou_valid"], label="Valid IoU")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
plt.figure(figsize=(10, 5))
plt.title("Dice Score")
plt.plot(results["dice_train"], label="Train Dice")
plt.plot(results["dice_valid"], label="Valid Dice")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
plt.figure(figsize=(10, 5))
plt.title("Acc Score")
plt.plot(results["acc_train"], label="Train Acc")
plt.plot(results["acc_valid"], label="Valid Acc")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
true_labels = []        
pred_labels = []                
iou_total = 0
dice_total = 0
model.eval()                

with torch.no_grad():                        
    for i, (images, masks, targets) in enumerate(test_loader):
        
        images = images.to(device)
        masks = masks.to(device)
        targets = targets.to(device)
        
        output_class, output_seg = model(images)             
        _, preds = torch.max(output_class, 1)                

        # Lưu lại các giá trị thật và dự đoán                
        true_labels.extend(targets.cpu().numpy())                
        pred_labels.extend(preds.cpu().numpy())                       

        iou = calculate_iou(output_seg, masks)
        dice = calculate_dice(output_seg, masks)

        iou_total+= iou.item()
        dice_total += dice.item()

# IoU score and Dice score
print(f'IoU score : {iou_total / len(test_loader)}')
print(f'Dice score : {dice_total / len(test_loader)}')

print('------------------------------------------')
# Tạo ma trận nhầm lẫn        
cm = confusion_matrix(true_labels, pred_labels)        
disp = ConfusionMatrixDisplay(confusion_matrix=cm)        

# Hiển thị ma trận nhầm lẫn        
disp.plot(cmap=plt.cm.Blues)        
plt.title("Confusion Matrix")        
plt.show()               

print(classification_report(true_labels, pred_labels, target_names = ['glioma', 'meningioma', 'no_tumor', 'pituitary'], digits = 4))
# Out:
# IoU score : 0.7973563224077225
# Dice score : 0.8560266382992268
# ------------------------------------------
#               precision    recall  f1-score   support
#
#       glioma     1.0000    0.9804    0.9901       102
#   meningioma     0.9858    0.9858    0.9858       141
#     no_tumor     0.9914    1.0000    0.9957       115
#    pituitary     0.9930    1.0000    0.9965       142
#
#     accuracy                         0.9920       500
#    macro avg     0.9926    0.9916    0.9920       500
# weighted avg     0.9920    0.9920    0.9920       500
